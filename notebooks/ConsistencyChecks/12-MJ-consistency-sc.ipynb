# %% [markdown]
# ## Consistency Check for Autoencodix with Single-Cell Data

# %%
## Download example data
# !wget https://cloud.scadsai.uni-leipzig.de/index.php/s/kmGkAzEw3wGZC95/download/scvelo_01_pancreas_adata_ncbi.h5ad
## move to data/raw
# !mv ./scvelo_01_pancreas_adata_ncbi.h5ad ../data/raw/
# Out:
# --2025-11-13 15:15:43--  https://cloud.scadsai.uni-leipzig.de/index.php/s/kmGkAzEw3wGZC95/download/scvelo_01_pancreas_adata_ncbi.h5ad
# Resolving cloud.scadsai.uni-leipzig.de (cloud.scadsai.uni-leipzig.de)... 139.18.13.37
# Connecting to cloud.scadsai.uni-leipzig.de (cloud.scadsai.uni-leipzig.de)|139.18.13.37|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 146049272 (139M) [application/octet-stream]
# Saving to: ‘scvelo_01_pancreas_adata_ncbi.h5ad’
#
# scvelo_01_pancreas_ 100%[===================>] 139.28M   106MB/s    in 1.3s
#
# 2025-11-13 15:15:44 (106 MB/s) - ‘scvelo_01_pancreas_adata_ncbi.h5ad’ saved [146049272/146049272]
