# %% [markdown]
# ## XModalix Workbook

# %% [markdown]
# #### IMPORTS

# %%
import os
from autoencodix.configs.default_config import DataConfig, DataInfo, DefaultConfig
from autoencodix.configs.xmodalix_config import XModalixConfig
import autoencodix as acx

notebook_dir = os.path.dirname(os.path.abspath("__file__"))
print(notebook_dir)
os.chdir(notebook_dir)
os.chdir("..")
print(os.getcwd())
# Out:
# /Users/maximilianjoas/development/autoencodix_package/notebooks
# /Users/maximilianjoas/development/autoencodix_package

# %% [markdown]
# #### GLOBALS
# **ATTENTION**
# Be sure to have the appropriate files, or adjust paths and make your own config

# %%
IMGROOT = os.path.join("data/images/ALY-2_SYS721/")
IMGMAPPING = os.path.join("data/ALY-2_SYS721_mappings.txt")
NUMFILE = os.path.join("data/AM3_NO2_raw_cell.tsv")

img_config = DefaultConfig(
    checkpoint_interval=25,
	loss_reduction = "sum",
    class_param="early",
    epochs=5,
	beta = 0.01,
    requires_paired=False,
	gamma= 2,
	delta_class= 0.0,
	delta_pair = 3,
	learning_rate=0.001,
	k_filter=1000,
	latent_dim=8,
    batch_size=181,
    # blablabla="",
    data_config=DataConfig(
        data_info={
            "IMG": DataInfo(
                file_path=IMGROOT,
                data_type="IMG",
				scaling="MINMAX",
                translate_direction="to",
                pretrain_epochs=30
            ),
            "RNA": DataInfo(
                file_path=NUMFILE,
                data_type="NUMERIC",
				scaling = "MINMAX",
                translate_direction="from",
            ),
            "RNA2": DataInfo(
                file_path=NUMFILE,
                data_type="NUMERIC",
            ),
            "ANNO": DataInfo(
                file_path=IMGMAPPING,
                data_type="ANNOTATION",
            ),
        },
    ),
)

# %% [markdown]
# ### Run Xmodalix with defined config
# - .run() does not work yet, because we dont have a visualizer, so we run it step by step

# %%
# %env CUBLAS_WORKSPACE_CONFIG=:16:8
# Out:
# env: CUBLAS_WORKSPACE_CONFIG=:16:8

# %%
xmodalix = acx.XModalix(config=img_config)
xmodalix.preprocess()
xmodalix.fit()
result = xmodalix.predict()
# Out:
# Given image size is possible, rescaling images to: 64x64
# Successfully loaded 260 images for IMG
# anno key: RNA
# anno key: RNA2
# anno key: IMG
# DP:
# multi_bulk:
#   RNA: 260 samples × 279 features
#   RNA2: 260 samples × 279 features
# annotation:
#   RNA: 260 samples × 3 features
#   RNA2: 260 samples × 3 features
#   IMG: 260 samples × 3 features
# img:
#   IMG: 260 items
# k: multi_sc
# k: multi_bulk
# k: annotation
# k: img
# k: from_modality
# k: to_modality
# DP:
# multi_bulk:
#   RNA: 260 samples × 279 features
#   RNA2: 260 samples × 279 features
# annotation:
#   RNA: 260 samples × 3 features
#   RNA2: 260 samples × 3 features
#   IMG: 260 samples × 3 features
# img:
#   IMG: 260 items
# k: multi_sc
# k: multi_bulk
# k: annotation
# k: img
# k: from_modality
# k: to_modality
# DP:
# multi_bulk:
#   RNA: 260 samples × 279 features
#   RNA2: 260 samples × 279 features
# annotation:
#   RNA: 260 samples × 3 features
#   RNA2: 260 samples × 3 features
#   IMG: 260 samples × 3 features
# img:
#   IMG: 260 items
# k: multi_sc
# k: multi_bulk
# k: annotation
# k: img
# k: from_modality
# k: to_modality
# Converting 182 images to torch.float32 tensors...
# Converting 52 images to torch.float32 tensors...
# Converting 26 images to torch.float32 tensors...
# key: train, type: <class 'dict'>
# key: valid, type: <class 'dict'>
# key: test, type: <class 'dict'>
# /Users/maximilianjoas/development/autoencodix_package/src/autoencodix/base/_base_pipeline.py:189: UserWarning: Your config is of type: <class 'autoencodix.configs.default_config.DefaultConfig'>, for this pipeline the default params of: <class 'autoencodix.configs.xmodalix_config.XModalixConfig'> work best
#   warnings.warn(
# /Users/maximilianjoas/development/autoencodix_package/src/autoencodix/utils/_bulkreader.py:226: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support sep=None with delim_whitespace=False; you can avoid this warning by specifying engine='python'.
#   return pd.read_csv(file_path, sep=sep, index_col=0)
# /Users/maximilianjoas/development/autoencodix_package/src/autoencodix/utils/_bulkreader.py:226: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support sep=None with delim_whitespace=False; you can avoid this warning by specifying engine='python'.
#   return pd.read_csv(file_path, sep=sep, index_col=0)
# /Users/maximilianjoas/development/autoencodix_package/src/autoencodix/utils/_bulkreader.py:226: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support sep=None with delim_whitespace=False; you can avoid this warning by specifying engine='python'.
#   return pd.read_csv(file_path, sep=sep, index_col=0)
# /Users/maximilianjoas/development/autoencodix_package/src/autoencodix/utils/_imgreader.py:264: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support sep=None with delim_whitespace=False; you can avoid this warning by specifying engine='python'.
#   annotation = pd.read_csv(anno_file, sep=sep)
# /Users/maximilianjoas/development/autoencodix_package/src/autoencodix/data/_filter.py:102: UserWarning: WARNING: k is None or greater than number of columns, keeping all features.
#   warnings.warn(
# /Users/maximilianjoas/development/autoencodix_package/src/autoencodix/data/_filter.py:102: UserWarning: WARNING: k is None or greater than number of columns, keeping all features.
#   warnings.warn(
# Check if we need to pretrain: multi_bulk.RNA
# pretrain epochs : 0
# No pretraining for multi_bulk.RNA
# Check if we need to pretrain: multi_bulk.RNA2
# pretrain epochs : 0
# No pretraining for multi_bulk.RNA2
# Check if we need to pretrain: img.IMG
# pretrain epochs : 30
# Starting Pretraining for: img.IMG with <class 'autoencodix.trainers._general_trainer.GeneralTrainer'>
# /Users/maximilianjoas/development/autoencodix_package/src/autoencodix
anneal_factor: 1.0000, effective_beta_factor: 0.0100
# Epoch 30 - Valid Loss: 181.4356
# Sub-losses: recon_loss: 181.4035, var_loss: 0.0321, anneal_factor: 1.0000, effective_beta_factor: 0.0100
# --- Epoch 1/5 ---
# split: train, n_samples: 3258
# Epoch 1/5 - Train Loss: 224.9415
# Sub-losses - total_loss: 224.9415, adver_loss: 2.5711, aggregated_sub_losses: 220.3196, paired_loss: 2.0508, class_loss: 0.0000, multi_bulk.RNA.recon_loss: 33.8331, multi_bulk.RNA.var_loss: 0.0000, multi_bulk.RNA.loss: 33.8331, multi_bulk.RNA2.recon_loss: 109.4694, multi_bulk.RNA2.var_loss: 0.0000, multi_bulk.RNA2.loss: 109.4694, img.IMG.recon_loss: 77.0170, img.IMG.var_loss: 0.0000, img.IMG.loss: 77.0170, clf_loss: 1.0831
# split: valid, n_samples: 1629
# Epoch 1/5 - Valid Loss: 312351.0703
# Sub-losses - total_loss: 191.7441, adver_loss: 2.3469, aggregated_sub_losses: 189.1784, paired_loss: 0.2188, class_loss: 0.0000, multi_bulk.RNA.recon_loss: 16.5241, multi_bulk.RNA.var_loss: 0.0000, multi_bulk.RNA.loss: 16.5241, multi_bulk.RNA2.recon_loss: 118.1183, multi_bulk.RNA2.var_loss: 0.0000, multi_bulk.RNA2.loss: 118.1183, img.IMG.recon_loss: 54.5360, img.IMG.var_loss: 0.0000, img.IMG.loss: 54.5360, clf_loss: 1.0477
# --- Epoch 2/5 ---
# split: train, n_samples: 3258
# Epoch 2/5 - Train Loss: 207.6856
# Sub-losses - total_loss: 207.6856, adver_loss: 2.8091, aggregated_sub_losses: 202.7962, paired_loss: 2.0803, class_loss: 0.0000, multi_bulk.RNA.recon_loss: 24.6949, multi_bulk.RNA.var_loss: 0.0000, multi_bulk.RNA.loss: 24.6949, multi_bulk.RNA2.recon_loss: 101.1072, multi_bulk.RNA2.var_loss: 0.0000, multi_bulk.RNA2.loss: 101.1072, img.IMG.recon_loss: 76.9939, img.IMG.var_loss: 0.0003, img.IMG.loss: 76.9941, clf_loss: 0.9933
# split: valid, n_samples: 1629
# Epoch 2/5 - Valid Loss: 299762.6094
# Sub-losses - total_loss: 184.0163, adver_loss: 2.4766, aggregated_sub_losses: 181.2943, paired_loss: 0.2455, class_loss: 0.0000, multi_bulk.RNA.recon_loss: 15.2612, multi_bulk.RNA.var_loss: 0.0000, multi_bulk.RNA.loss: 15.2612, multi_bulk.RNA2.recon_loss: 115.2978, multi_bulk.RNA2.var_loss: 0.0001, multi_bulk.RNA2.loss: 115.2979, img.IMG.recon_loss: 50.7351, img.IMG.var_loss: 0.0001, img.IMG.loss: 50.7351, clf_loss: 1.0151
# --- Epoch 3/5 ---
# split: train, n_samples: 3258
# Epoch 3/5 - Train Loss: 197.7339
# Sub-losses - total_loss: 197.7339, adver_loss: 2.8076, aggregated_sub_losses: 192.8522, paired_loss: 2.0740, class_loss: 0.0000, multi_bulk.RNA.recon_loss: 19.3037, multi_bulk.RNA.var_loss: 0.0007, multi_bulk.RNA.loss: 19.3044, multi_bulk.RNA2.recon_loss: 96.4900, multi_bulk.RNA2.var_loss: 0.0015, multi_bulk.RNA2.loss: 96.4915, img.IMG.recon_loss: 77.0434, img.IMG.var_loss: 0.0130, img.IMG.loss: 77.0564, clf_loss: 0.9191
# split: valid, n_samples: 1629
# Epoch 3/5 - Valid Loss: 277692.5703
# Sub-losses - total_loss: 170.4681, adver_loss: 2.5683, aggregated_sub_losses: 167.6392, paired_loss: 0.2607, class_loss: 0.0000, multi_bulk.RNA.recon_loss: 12.8073, multi_bulk.RNA.var_loss: 0.0004, multi_bulk.RNA.loss: 12.8077, multi_bulk.RNA2.recon_loss: 105.3785, multi_bulk.RNA2.var_loss: 0.0034, multi_bulk.RNA2.loss: 105.3820, img.IMG.recon_loss: 49.4437, img.IMG.var_loss: 0.0059, img.IMG.loss: 49.4496, clf_loss: 0.9399
# --- Epoch 4/5 ---
# split: train, n_samples: 3258
# Epoch 4/5 - Train Loss: 190.6599
# Sub-losses - total_loss: 190.6599, adver_loss: 2.7352, aggregated_sub_losses: 185.8252, paired_loss: 2.0996, class_loss: 0.0000, multi_bulk.RNA.recon_loss: 15.8820, multi_bulk.RNA.var_loss: 0.0048, multi_bulk.RNA.loss: 15.8868, multi_bulk.RNA2.recon_loss: 92.8822, multi_bulk.RNA2.var_loss: 0.0108, multi_bulk.RNA2.loss: 92.8930, img.IMG.recon_loss: 76.9494, img.IMG.var_loss: 0.0960, img.IMG.loss: 77.0454, clf_loss: 0.8649
# split: valid, n_samples: 1629
# Epoch 4/5 - Valid Loss: 290091.6719
# Sub-losses - total_loss: 178.0796, adver_loss: 2.5717, aggregated_sub_losses: 175.2327, paired_loss: 0.2751, class_loss: 0.0000, multi_bulk.RNA.recon_loss: 11.8286, multi_bulk.RNA.var_loss: 0.0049, multi_bulk.RNA.loss: 11.8335, multi_bulk.RNA2.recon_loss: 111.6758, multi_bulk.RNA2.var_loss: 0.0215, multi_bulk.RNA2.loss: 111.6972, img.IMG.recon_loss: 51.6425, img.IMG.var_loss: 0.0595, img.IMG.loss: 51.7020, clf_loss: 0.8446
# --- Epoch 5/5 ---
# split: train, n_samples: 3258
# Epoch 5/5 - Train Loss: 183.9614
# Sub-losses - total_loss: 183.9614, adver_loss: 2.7954, aggregated_sub_losses: 179.0723, paired_loss: 2.0937, class_loss: 0.0000, multi_bulk.RNA.recon_loss: 13.7515, multi_bulk.RNA.var_loss: 0.0056, multi_bulk.RNA.loss: 13.7571, multi_bulk.RNA2.recon_loss: 88.0997, multi_bulk.RNA2.var_loss: 0.0133, multi_bulk.RNA2.loss: 88.1130, img.IMG.recon_loss: 77.0934, img.IMG.var_loss: 0.1088, img.IMG.loss: 77.2022, clf_loss: 0.8351
# split: valid, n_samples: 1629
# Epoch 5/5 - Valid Loss: 276082.5859
# Sub-losses - total_loss: 169.4798, adver_loss: 2.7577, aggregated_sub_losses: 166.4361, paired_loss: 0.2859, class_loss: 0.0000, multi_bulk.RNA.recon_loss: 10.2747, multi_bulk.RNA.var_loss: 0.0105, multi_bulk.RNA.loss: 10.2852, multi_bulk.RNA2.recon_loss: 100.0381, multi_bulk.RNA2.var_loss: 0.0225, multi_bulk.RNA2.loss: 100.0606, img.IMG.recon_loss: 56.0065, img.IMG.var_loss: 0.0838, img.IMG.loss: 56.0903, clf_loss: 0.7749
# Storing checkpoint for epoch 4...
# Prediction complete.
# Processing latent space results into a single AnnData object...
# Identified source modality for latent space: 'multi_bulk.RNA'
#   - Added 279 source feature IDs to .uns
# Finished processing latent results.

# %% [markdown]
# ## Getting Translation and Sample Ids for all splits

# %% [markdown]
# #### First select predict_all = True

# %%
result = xmodalix.predict(predict_all=True)
# Out:
# Prediction complete.
# Processing latent space results into a single AnnData object...
# Identified source modality for latent space: 'multi_bulk.RNA'
#   - Added 279 source feature IDs to .uns
# Finished processing latent results.
# Prediction complete.
# Prediction complete.

# %%
test_translation = result.reconstructions.get(epoch=-1, split="test")["translation"]
print("Test prints: ")
print("=" * 50)
print(f" translation shape: {test_translation.shape}") # (n_samples, n_channels, height, width) here (121,1,64,64)
# sample ids are connected to data modalities and splits
test_sample_ids = result.sample_ids.get(epoch=-1, split="test")
print(f"Data modality keys for translation: {test_sample_ids.keys()}")
print(f"First 4 sample ids for translation: {test_sample_ids['translation'][0:4]}")


# this works analogously for train and valid splits
print("\n\nTrain prints: ")
print("=" * 50)
train_translation = result.reconstructions.get(epoch=-1, split="train")["translation"]
print(f" translation shape: {train_translation.shape}")
train_sample_ids = result.sample_ids.get(epoch=-1, split="train")
print(f"Data modality keys for translation: {train_sample_ids.keys()}")
print(f"First 4 sample ids for translation: {train_sample_ids['translation'][0:4]}") # first 4 sample ids of the translation modality


print("\n\nValid prints: ")
print("=" * 50)

valid_translation = result.reconstructions.get(epoch=-1, split="valid")["translation"]
print(f" translation shape: {valid_translation.shape}")
valid_sample_ids = result.sample_ids.get(epoch=-1, split="valid")
print(f"Data modality keys for translation: {valid_sample_ids.keys()}")
print(f"First 4 sample ids for translation: {valid_sample_ids['translation'][0:4]}") # first 4 sample ids of the translation modality
# Out:
# Test prints:
# ==================================================
#  translation shape: (52, 1, 64, 64)
# Data modality keys for translation: dict_keys(['multi_bulk.RNA', 'multi_bulk.RNA2', 'img.IMG', 'translation', 'reference_img.IMG_to_img.IMG'])
# First 4 sample ids for translation: ['T_10' 'T_101' 'T_115' 'T_124']
#
#
# Train prints:
# ==================================================
#  translation shape: (182, 1, 64, 64)
# Data modality keys for translation: dict_keys(['multi_bulk.RNA', 'multi_bulk.RNA2', 'img.IMG', 'translation', 'reference_img.IMG_to_img.IMG'])
# First 4 sample ids for translation: ['T_1' 'T_100' 'T_102' 'T_103']
#
#
# Valid prints:
# ==================================================
#  translation shape: (26, 1, 64, 64)
# Data modality keys for translation: dict_keys(['multi_bulk.RNA', 'multi_bulk.RNA2', 'img.IMG', 'translation', 'reference_img.IMG_to_img.IMG'])
# First 4 sample ids for translation: ['T_105' 'T_108' 'T_117' 'T_128']

# %% [markdown]
# ### Loading and Saving XModalix
# - works like for other pipelines too, can be used to run another predict pairing also

# %%
len(xmodalix._datasets.train.datasets["multi_bulk.RNA"])
# Out:
# 182

# %%
loader = xmodalix._trainer._trainloader
for batch in loader:
    print(batch)
    break
# Out:
# {'multi_bulk.RNA': {'data': tensor([[7.9554e-02, 1.3243e-01, 2.9674e-02,  ..., 4.6382e-03, 0.0000e+00,
#          1.5136e-04],
#         [6.1737e-01, 7.8385e-01, 8.7580e-01,  ..., 9.1238e-01, 5.7441e-01,
#          8.8791e-01],
#         [6.5911e-01, 7.4355e-01, 7.8450e-01,  ..., 9.1650e-01, 6.2575e-01,
#          8.3916e-01],
#         ...,
#         [2.4647e-01, 4.2170e-01, 4.8870e-01,  ..., 3.9173e-01, 2.7967e-01,
#          9.0442e-02],
#         [5.5255e-01, 4.8280e-01, 1.0000e+00,  ..., 8.7532e-01, 3.2250e-01,
#          7.0970e-01],
#         [3.2956e-01, 1.1504e-01, 2.2317e-01,  ..., 5.4705e-03, 6.5266e-01,
#          0.0000e+00]], device='mps:0'), 'metadata':                    img_paths extra_class_labels early
# T_64    ALY-2_SYS721_t64.tif                 64   '0'
# T_229  ALY-2_SYS721_t229.tif                229   '0'
# T_234  ALY-2_SYS721_t234.tif                234   '0'
# T_244  ALY-2_SYS721_t244.tif                244   '0'
# T_32    ALY-2_SYS721_t32.tif                 32   '1'
# ...                      ...                ...   ...
# T_121  ALY-2_SYS721_t121.tif                121   '0'
# T_237  ALY-2_SYS721_t237.tif                237   '0'
# T_122  ALY-2_SYS721_t122.tif                122   '0'
# T_170  ALY-2_SYS721_t170.tif                170   '0'
# T_28    ALY-2_SYS721_t28.tif                 28   '1'
#
# [181 rows x 3 columns], 'sample_ids': [np.str_('T_64'), np.str_('T_229'), np.str_('T_234'), np.str_('T_244'), np.str_('T_32'), np.str_('T_250'), np.str_('T_49'), np.str_('T_186'), np.str_('T_129'), np.str_('T_61'), np.str_('T_81'), np.str_('T_225'), np.str_('T_169'), np.str_('T_137'), np.str_('T_208'), np.str_('T_73'), np.str_('T_200'), np.str_('T_242'), np.str_('T_1'), np.str_('T_59'), np.str_('T_138'), np.str_('T_165'), np.str_('T_239'), np.str_('T_203'), np.str_('T_119'), np.str_('T_2'), np.str_('T_50'), np.str_('T_176'), np.str_('T_139'), np.str_('T_106'), np.str_('T_45'), np.str_('T_145'), np.str_('T_209'), np.str_('T_181'), np.str_('T_55'), np.str_('T_125'), np.str_('T_63'), np.str_('T_80'), np.str_('T_126'), np.str_('T_132'), np.str_('T_86'), np.str_('T_220'), np.str_('T_111'), np.str_('T_185'), np.str_('T_12'), np.str_('T_191'), np.str_('T_226'), np.str_('T_52'), np.str_('T_231'), np.str_('T_113'), np.str_('T_96'), np.str_('T_118'), np.str_('T_146'), np.str_('T_243'), np.str_('T_212'), np.str_('T_174'), np.str_('T_207'), np.str_('T_140'), np.str_('T_97'), np.str_('T_3'), np.str_('T_85'), np.str_('T_72'), np.str_('T_41'), np.str_('T_260'), np.str_('T_33'), np.str_('T_16'), np.str_('T_57'), np.str_('T_190'), np.str_('T_13'), np.str_('T_74'), np.str_('T_193'), np.str_('T_197'), np.str_('T_43'), np.str_('T_158'), np.str_('T_195'), np.str_('T_4'), np.str_('T_26'), np.str_('T_171'), np.str_('T_37'), np.str_('T_94'), np.str_('T_110'), np.str_('T_27'), np.str_('T_76'), np.str_('T_102'), np.str_('T_29'), np.str_('T_241'), np.str_('T_236'), np.str_('T_167'), np.str_('T_180'), np.str_('T_175'), np.str_('T_11'), np.str_('T_134'), np.str_('T_221'), np.str_('T_161'), np.str_('T_14'), np.str_('T_99'), np.str_('T_84'), np.str_('T_5'), np.str_('T_75'), np.str_('T_166'), np.str_('T_58'), np.str_('T_178'), np.str_('T_103'), np.str_('T_78'), np.str_('T_179'), np.str_('T_164'), np.str_('T_104'), np.str_('T_46'), np.str_('T_233'), np.str_('T_112'), np.str_('T_163'), np.str_('T_198'), np.str_('T_256'), np.str_('T_88'), np.str_('T_162'), np.str_('T_77'), np.str_('T_65'), np.str_('T_224'), np.str_('T_155'), np.str_('T_38'), np.str_('T_60'), np.str_('T_172'), np.str_('T_205'), np.str_('T_252'), np.str_('T_187'), np.str_('T_90'), np.str_('T_131'), np.str_('T_42'), np.str_('T_93'), np.str_('T_149'), np.str_('T_20'), np.str_('T_189'), np.str_('T_69'), np.str_('T_160'), np.str_('T_23'), np.str_('T_48'), np.str_('T_120'), np.str_('T_109'), np.str_('T_188'), np.str_('T_100'), np.str_('T_107'), np.str_('T_183'), np.str_('T_257'), np.str_('T_194'), np.str_('T_230'), np.str_('T_249'), np.str_('T_253'), np.str_('T_114'), np.str_('T_70'), np.str_('T_227'), np.str_('T_196'), np.str_('T_133'), np.str_('T_25'), np.str_('T_214'), np.str_('T_211'), np.str_('T_68'), np.str_('T_148'), np.str_('T_202'), np.str_('T_35'), np.str_('T_123'), np.str_('T_213'), np.str_('T_184'), np.str_('T_150'), np.str_('T_21'), np.str_('T_9'), np.str_('T_223'), np.str_('T_116'), np.str_('T_219'), np.str_('T_47'), np.str_('T_89'), np.str_('T_201'), np.str_('T_238'), np.str_('T_192'), np.str_('T_40'), np.str_('T_216'), np.str_('T_153'), np.str_('T_121'), np.str_('T_237'), np.str_('T_122'), np.str_('T_170'), np.str_('T_28')], 'sampled_index': [42, 162, 166, 174, 19, 176, 32, 128, 89, 40, 55, 159, 114, 94, 147, 48, 141, 172, 0, 38, 95, 111, 170, 144, 82, 1, 33, 120, 96, 72, 28, 98, 148, 124, 35, 87, 41, 54, 88, 91, 58, 155, 76, 127, 7, 133, 160, 34, 164, 78, 65, 81, 99, 173, 150, 118, 146, 97, 66, 2, 57, 47, 25, 181, 20, 10, 36, 132, 8, 49, 135, 139, 27, 105, 137, 3, 15, 116, 22, 64, 75, 16, 51, 69, 18, 171, 167, 113, 123, 119, 6, 93, 156, 107, 9, 67, 56, 4, 50, 112, 37, 121, 70, 53, 122, 110, 71, 29, 165, 77, 109, 140, 179, 60, 108, 52, 43, 158, 104, 23, 39, 117, 145, 177, 129, 62, 90, 26, 63, 101, 11, 131, 45, 106, 13, 31, 83, 74, 130, 68, 73, 125, 180, 136, 163, 175, 178, 79, 46, 161, 138, 92, 14, 152, 149, 44, 100, 143, 21, 86, 151, 126, 102, 12, 5, 157, 80, 154, 30, 61, 142, 169, 13 ...
#         [ 0.9941,  1.3041,  1.0238,  ...,  1.2149,  1.1902,  1.2659],
#         [ 1.1563,  1.1517,  0.7756,  ...,  1.2259,  1.4039,  1.1436],
#         ...,
#         [-0.4471, -0.0658, -0.0285,  ..., -0.1741, -0.0371, -0.7350],
#         [ 0.7422,  0.1653,  1.3614,  ...,  1.1160,  0.1413,  0.8188],
#         [-0.1242, -1.2259, -0.7503,  ..., -1.2046,  1.5160, -0.9619]],
#        device='mps:0'), 'metadata':                    img_paths extra_class_labels early
# T_64    ALY-2_SYS721_t64.tif                 64   '0'
# T_229  ALY-2_SYS721_t229.tif                229   '0'
# T_234  ALY-2_SYS721_t234.tif                234   '0'
# T_244  ALY-2_SYS721_t244.tif                244   '0'
# T_32    ALY-2_SYS721_t32.tif                 32   '1'
# ...                      ...                ...   ...
# T_121  ALY-2_SYS721_t121.tif                121   '0'
# T_237  ALY-2_SYS721_t237.tif                237   '0'
# T_122  ALY-2_SYS721_t122.tif                122   '0'
# T_170  ALY-2_SYS721_t170.tif                170   '0'
# T_28    ALY-2_SYS721_t28.tif                 28   '1'
#
# [181 rows x 3 columns], 'sample_ids': [np.str_('T_64'), np.str_('T_229'), np.str_('T_234'), np.str_('T_244'), np.str_('T_32'), np.str_('T_250'), np.str_('T_49'), np.str_('T_186'), np.str_('T_129'), np.str_('T_61'), np.str_('T_81'), np.str_('T_225'), np.str_('T_169'), np.str_('T_137'), np.str_('T_208'), np.str_('T_73'), np.str_('T_200'), np.str_('T_242'), np.str_('T_1'), np.str_('T_59'), np.str_('T_138'), np.str_('T_165'), np.str_('T_239'), np.str_('T_203'), np.str_('T_119'), np.str_('T_2'), np.str_('T_50'), np.str_('T_176'), np.str_('T_139'), np.str_('T_106'), np.str_('T_45'), np.str_('T_145'), np.str_('T_209'), np.str_('T_181'), np.str_('T_55'), np.str_('T_125'), np.str_('T_63'), np.str_('T_80'), np.str_('T_126'), np.str_('T_132'), np.str_('T_86'), np.str_('T_220'), np.str_('T_111'), np.str_('T_185'), np.str_('T_12'), np.str_('T_191'), np.str_('T_226'), np.str_('T_52'), np.str_('T_231'), np.str_('T_113'), np.str_('T_96'), np.str_('T_118'), np.str_('T_146'), np.str_('T_243'), np.str_('T_212'), np.str_('T_174'), np.str_('T_207'), np.str_('T_140'), np.str_('T_97'), np.str_('T_3'), np.str_('T_85'), np.str_('T_72'), np.str_('T_41'), np.str_('T_260'), np.str_('T_33'), np.str_('T_16'), np.str_('T_57'), np.str_('T_190'), np.str_('T_13'), np.str_('T_74'), np.str_('T_193'), np.str_('T_197'), np.str_('T_43'), np.str_('T_158'), np.str_('T_195'), np.str_('T_4'), np.str_('T_26'), np.str_('T_171'), np.str_('T_37'), np.str_('T_94'), np.str_('T_110'), np.str_('T_27'), np.str_('T_76'), np.str_('T_102'), np.str_('T_29'), np.str_('T_241'), np.str_('T_236'), np.str_('T_167'), np.str_('T_180'), np.str_('T_175'), np.str_('T_11'), np.str_('T_134'), np.str_('T_221'), np.str_('T_161'), np.str_('T_14'), np.str_('T_99'), np.str_('T_84'), np.str_('T_5'), np.str_('T_75'), np.str_('T_166'), np.str_('T_58'), np.str_('T_178'), np.str_('T_103'), np.str_('T_78'), np.str_('T_179'), np.str_('T_164'), np.str_('T_104'), np.str_('T_46'), np.str_('T_233'), np.str_('T_112'), np.str_('T_163'), np.str_('T_198'), np.str_('T_256'), np.str_('T_88'), np.str_('T_162'), np.str_('T_77'), np.str_('T_65'), np.str_('T_224'), np.str_('T_155'), np.str_('T_38'), np.str_('T_60'), np.str_('T_172'), np.str_('T_205'), np.str_('T_252'), np.str_('T_187'), np.str_('T_90'), np.str_('T_131'), np.str_('T_42'), np.str_('T_93'), np.str_('T_149'), np.str_('T_20'), np.str_('T_189'), np.str_('T_69'), np.str_('T_160'), np.str_('T_23'), np.str_('T_48'), np.str_('T_120'), np.str_('T_109'), np.str_('T_188'), np.str_('T_100'), np.str_('T_107'), np.str_('T_183'), np.str_('T_257'), np.str_('T_194'), np.str_('T_230'), np.str_('T_249'), np.str_('T_253'), np.str_('T_114'), np.str_('T_70'), np.str_('T_227'), np.str_('T_196'), np.str_('T_133'), np.str_('T_25'), np.str_('T_214'), np.str_('T_211'), np.str_('T_68'), np.str_('T_148'), np.str_('T_202'), np.str_('T_35'), np.str_('T_123'), np.str_('T_213'), np.str_('T_184'), np.str_('T_150'), np.str_('T_21'), np.str_('T_9'), np.str_('T_223'), np.str_('T_116'), np.str_('T_219'), np.str_('T_47'), np.str_('T_89'), np.str_('T_201'), np.str_('T_238'), np.str_('T_192'), np.str_('T_40'), np.str_('T_216'), np.str_('T_153'), np.str_('T_121'), np.str_('T_237'), np.str_('T_122'), np.str_('T_170'), np.str_('T_28')], 'sampled_index': [42, 162, 166, 174, 19, 176, 32, 128, 89, 40
#             2.8169e-02, -3.7253e-09]]],
#
#
#         ...,
#
#
#         [[[ 6.8182e-02,  6.8182e-02,  6.8182e-02,  ...,  4.5455e-02,
#             4.5455e-02,  6.8182e-02],
#           [ 4.5455e-02,  6.8182e-02,  4.5455e-02,  ...,  4.5455e-02,
#             4.5455e-02,  4.5455e-02],
#           [ 4.5455e-02,  6.8182e-02,  6.8182e-02,  ...,  6.8182e-02,
#             4.5455e-02,  4.5455e-02],
#           ...,
#           [ 2.2727e-02,  4.5455e-02,  2.2727e-02,  ...,  4.5455e-02,
#             4.5455e-02,  0.0000e+00],
#           [ 2.2727e-02,  4.5455e-02,  4.5455e-02,  ...,  0.0000e+00,
#             0.0000e+00,  0.0000e+00],
#           [ 2.2727e-02,  4.5455e-02,  2.2727e-02,  ...,  4.5455e-02,
#             2.2727e-02,  0.0000e+00]]],
#
#
#         [[[ 5.4795e-02,  6.8493e-02,  6.8493e-02,  ...,  6.8493e-02,
#             4.1096e-02,  5.4795e-02],
#           [ 4.1096e-02,  5.4795e-02,  6.8493e-02,  ...,  4.1096e-02,
#             5.4795e-02,  4.1096e-02],
#           [ 5.4795e-02,  5.4795e-02,  5.4795e-02,  ...,  4.1096e-02,
#             5.4795e-02,  4.1096e-02],
#           ...,
#           [ 4.1096e-02,  4.1096e-02,  1.3699e-02,  ...,  2.7397e-02,
#             1.3699e-02,  0.0000e+00],
#           [ 1.3699e-02,  1.3699e-02,  4.1096e-02,  ...,  2.7397e-02,
#             1.3699e-02,  0.0000e+00],
#           [ 2.7397e-02,  2.7397e-02,  2.7397e-02,  ...,  2.7397e-02,
#             1.3699e-02,  0.0000e+00]]],
#
#
#         [[[ 5.7143e-02,  2.8571e-02,  5.7143e-02,  ...,  5.7143e-02,
#             2.8571e-02,  2.8571e-02],
#           [ 2.8571e-02,  2.8571e-02,  2.8571e-02,  ...,  2.8571e-02,
#             2.8571e-02,  2.8571e-02],
#           [ 2.8571e-02,  2.8571e-02,  2.8571e-02,  ...,  2.8571e-02,
#             2.8571e-02,  2.8571e-02],
#           ...,
#           [-1.8626e-09, -1.8626e-09,  2.8571e-02,  ..., -1.8626e-09,
#            -1.8626e-09, -1.8626e-09],
#           [-1.8626e-09, -1.8626e-09, -1.8626e-09,  ..., -1.8626e-09,
#            -1.8626e-09, -1.8626e-09],
#           [ 2.8571e-02, -1.8626e-09, -1.8626e-09,  ..., -1.8626e-09,
#            -1.8626e-09, -1.8626e-09]]]], device='mps:0'), 'metadata':                    img_paths extra_class_labels early
# T_64    ALY-2_SYS721_t64.tif                 64   '0'
# T_229  ALY-2_SYS721_t229.tif                229   '0'
# T_234  ALY-2_SYS721_t234.tif                234   '0'
# T_244  ALY-2_SYS721_t244.tif                244   '0'
# T_32    ALY-2_SYS721_t32.tif                 32   '1'
# ...                      ...                ...   ...
# T_121  ALY-2_SYS721_t121.tif                121   '0'
# T_237  ALY-2_SYS721_t237.tif                237   '0'
# T_122  ALY-2_SYS721_t122.tif                122   '0'
# T_170  ALY-2_SYS721_t170.tif                170   '0'
# T_28    ALY-2_SYS721_t28.tif                 28   '1'
#
# [181 rows x 3 columns], 'sample_ids': [np.str_('T_64'), np.str_('T_229'), np.str_('T_234'), np.str_('T_244'), np.str_('T_32'), np.str_('T_250'), np.str_('T_49'), np.str_('T_186'), np.str_('T_129'), np.str_('T_61'), np.str_('T_81'), np.str_('T_225'), np.str_('T_169'), np.str_('T_137'), np.str_('T_208'), np.str_('T_73'), np.str_('T_200'), np.str_('T_242'), np.str_('T_1'), np.str_('T_59'), np.str_('T_138'), np.str_('T_165'), np.str_('T_239'), np.str_('T_203'), np.str_('T_119'), np.str_('T_2'), np.str_('T_50'), np.str_('T_176'), np.str_('T_139'), np.str_('T_106'), np.str_('T_45'), np.str_('T_145'), np.str_('T_209'), np.str_('T_181'), np.str_('T_55'), np.str_('T_125'), np.str_('T_63'), np.str_('T_80'), np.str_('T_126'), np.str_('T_132'), np.str_('T_86'), np.str_('T_220'), np.str_('T_111'), np.str_('T_185'), np.str_('T_12'), np.str_('T_191'), np.str_('T_226'), np.str_('T_52'), np.str_('T_231'), np.str_('T_113'), np.str_('T_96'), np.str_('T_118'), np.str_('T_146'), np.str_('T_243'), np.str_('T_212'), np.str_('T_174'), np.str_('T_207'), np.str_('T_140'), np.str_('T_97'), np.str_('T_3'), np.str_('T_85'), np.str_('T_72'), np.str_('T_41'), np.str_('T_260'), np.str_('T_33'), np.str_('T_16'), np.str_('T_57'), np.str_('T_190'), np.str_('T_13'), np.str_('T_74'), np.str_('T_193'), np.str_('T_197'), np.str_('T_43'), np.str_('T_158'), np.str_('T_195'), np.str_('T_4'), np.str_('T_26'), np.str_('T_171'), np.str_('T_37'), np.str_('T_94'), np.str_('T_110'), np.str_('T_27'), np.str_('T_76'), np.str_('T_102'), np.str_('T_29'), np.str_('T_241'), np.str_('T_236'), np.str_('T_167'), np.str_('T_180'), np.str_('T_175'), np.str_('T_11'), np.str_('T_134'), np.str_('T_221'), np.str_('T_161'), np.str_('T_14'), np.str_('T_99'), np.str_('T_84'), np.str_('T_5'), np.str_('T_75'), np.str_('T_166'), np.str_('T_58'), np.str_('T_178'), np.str_('T_103'), np.str_('T_78'), np.str_('T_179'), np.str_('T_164'), np.str_('T_104'), np.str_('T_46'), np.str_('T_233'), np.str_('T_112'), np.str_('T_163'), np.str_('T_198'), np.str_('T_256'), np.str_('T_88'), np.str_('T_162'), np.str_('T_77'), np.str_('T_65'), np.str_('T_224'), np.str_('T_155'), np.str_('T_38'), np.str_('T_60'), np.str_('T_172'), np.str_('T_205'), np.str_('T_252'), np.str_('T_187'), np.str_('T_90'), np.str_('T_131'), np.str_('T_42'), np.str_('T_93'), np.str_('T_149'), np.str_('T_20'), np.str_('T_189'), np.str_('T_69'), np.str_('T_160'), np.str_('T_23'), np.str_('T_48'), np.str_('T_120'), np.str_('T_109'), np.str_('T_188'), np.str_('T_100'), np.str_('T_107'), np.str_('T_183'), np.str_('T_257'), np.str_('T_194'), np.str_('T_230'), np.str_('T_249'), np.str_('T_253'), np.str_('T_114'), np.str_('T_70'), np.str_('T_227'), np.str_('T_196'), np.str_('T_133'), np.str_('T_25'), np.str_('T_214'), np.str_('T_211'), np.str_('T_68'), np.str_('T_148'), np.str_('T_202'), np.str_('T_35'), np.str_('T_123'), np.str_('T_213'), np.str_('T_184'), np.str_('T_150'), np.str_('T_21'), np.str_('T_9'), np.str_('T_223'), np.str_('T_116'), np.str_('T_219'), np.str_('T_47'), np.str_('T_89'), np.str_('T_201'), np.str_('T_238'), np.str_('T_192'), np.str_('T_40'), np.str_('T_216'), np.str_('T_153'), np.str_('T_121'), np.str_('T_237'), np.str_('T_122'), np.str_('T_170'), np.str_('T_28')], 'sampled_index': [88, 32, 93, 169, 0, 170, 132, 125, 4, 136, 67, 140, 104, 164, 94, 101, 34, 157, 127, 99, 26, 59, 80, 50, 181, 149, 41, 40, 20, 13, 27, 130, 95, 91, 85, 179, 129, 62, 173, 172, 29, 92, 21, 144, 159, 145, 121, 44, 141, 17, 81, 175, 146, 154, 66, 45, 65, 114, 76, 134, 47, 112, 84, 10, 6, 176, 61, 137, 151, 148, 120, 110, 58, 71, 90, 113, 3, 60, 22, 63, 25, 5, 117, 12, 167, 163, 108, 83, 97, 54, 165, 160, 96, 55, 171, 109, 52, 102, 133, 74, 89, 115, 8, 38, 131, 70, 24, 43, 123, 15, 28, 82, 156, 126, 39, 128, 100, 143, 103, 162, 147, 73, 79, 177, 119, 51, 180, 69, 37, 53, 14, 35, 86, 42, 23, 150, 158, 153, 30, 2, 18, 111, 155, 98, 142, 9, 178, 1, 87, 122, 105, 168, 7, 33, 78, 72, 46, 49, 16, 166, 64, 138, 116, 19, 57, 107, 11, 139, 56, 118, 31, 77, 124 ...

# %%
f = next(iter(batch))
f
# Out:
# 'multi_bulk.RNA'

# %%
xmodalix.save("xmodalix.pkl")
# Out:
# Pipeline object saved successfully.
# Preprocessor saved successfully.
# Model state saved successfully.

# %%
xmodalix = acx.XModalix.load("xmodalix.pkl")
# Out:
# Attempting to load a pipeline from xmodalix.pkl...
# Pipeline object loaded successfully. Actual type: XModalix
# Preprocessor loaded successfully.
# Model state loaded successfully.

# %% [markdown]
# ### Inspect X-Modalix Result

# %%
r = xmodalix.result

# %% [markdown]
# Trainingdynamics in result are a dict with keys for each datamodality, the get interface works like for the other pipelines.
# We have the special keys:
# - translation which is the actual translated reconstruction or the from_latent space for the latentspace dynamic

# %%
r.reconstructions.get(epoch=-1, split="test").keys()
# Out:
# dict_keys(['multi_bulk.RNA', 'multi_bulk.RNA2', 'img.IMG', 'translation', 'reference_img.IMG_to_img.IMG'])

# %% [markdown]
# We have latentspaces for the test set for each modality, not only for the translation pairing

# %%
r.latentspaces.get(epoch=-1, split="test")
# Out:
# {'multi_bulk.RNA': array([[ 5.63161314e-01,  8.35161731e-02, -6.37044072e-01,
#          -7.96759188e-01,  2.83648551e-01,  2.13616371e+00,
#           2.48227978e+00,  1.84033656e+00],
#         [ 7.50749052e-01,  5.62994540e-01,  2.08419129e-01,
#           1.43759334e+00, -1.14015114e+00, -1.91308677e+00,
#           6.78302884e-01,  8.08669627e-01],
#         [-5.95399678e-01,  1.10475183e-01, -1.59708726e+00,
#          -7.53292441e-02,  2.43696213e+00, -8.06287766e-01,
#           1.30048603e-01, -7.47984529e-01],
#         [-6.11391127e-01, -3.18678826e-01,  1.54706940e-01,
#           1.10839617e+00,  2.44088173e-02,  7.84554601e-01,
#           9.85863924e-01,  6.85309708e-01],
#           1.0359465e+00,  2.1086669e+00, -1.0859742e+00,  9.1291934e-01],
#         [ 1.0365373e+00,  2.8382485e+00, -1.3992168e+00, -1.0526183e+00,
#           1.4449803e+00,  4.0206736e-01,  9.4447933e-02,  1.3706506e+00],
#         [ 1.8637950e+00,  1.8005546e+00,  5.7586819e-01, -1.9829929e+00,
#           7.7811533e-01,  2.9121822e-01,  2.1589851e+00,  3.8708025e-01],
#         [-3.8706875e-01,  2.6439729e+00, -2.9848582e-01,  4.8905265e-01,
#           1.3227619e+00, -3.5910887e-01,  6.3356262e-01, -5.7812142e-01],
#         [ 9.9504203e-02,  3.0499547e+00, -2.5823164e-01,  1.5955877e-01,
#           1.6315809e+00, -7.8815341e-02, -3.4016189e-01, -3.5372940e-01],
#         [-3.7042406e-01,  7.8228843e-01, -8.3786601e-01,  5.8605057e-01,
#          -1.4585513e+00, -9.1264203e-02, -1.5470362e+00,  1.6860428e+00],
#         [-5.2527231e-01,  1.3215487e+00,  1.2778100e+00, -8.2278973e-01,
#           1.0554854e+00, -1.5530320e+00,  1.5877181e+00,  3.6633089e-02],
#         [ 9.0129530e-01,  2.2835035e+00,  1.1685649e+00, -3.3296588e-01,
#          -1.0238483e+00,  3.2765946e+00, -2.6018333e+00,  1.5232431e+00],
#         [-9.0982771e-01,  1.4523803e+00,  1.4981552e-02,  1.2529263e+00,
#          -2.3087920e-01,  2.1526849e-01, -7.2432715e-01,  9.5615886e-02],
#         [-3.8438573e-01,  3.3910449e+00,  1.0859622e+00,  8.1639916e-01,
#          -1.1389002e+00, -6.0156584e-03, -1.0951086e+00,  9.8547912e-01],
#         [ 4.1781697e-01,  9.7839934e-01, -1.3959204e+00,  2.5357145e-01,
#          -9.6801758e-01,  7.2090000e-01, -2.8816932e-01,  2.3575857e-01],
#         [-5.3088206e-01,  5.1179471e+00,  1.1213299e+00, -7.0402229e-01,
#          -7.2215468e-01,  2.8413320e+00, -2.8427935e+00,  3.2116514e-01],
#         [-4.7324750e-01,  3.6758349e+00,  8.5180104e-01, -9.8917639e-01,
#          -1.0621994e+00,  4.4556494e+00,  1.7791605e+00,  5.2028161e-01]],
#        dtype=float32)}

# %% [markdown]
# We also provide the andata interface for the translate latentspace (from_modality)

# %%
r.adata_latent.obs_names
# Out:
# Index(['T_10', 'T_101', 'T_115', 'T_124', 'T_127', 'T_136', 'T_142', 'T_143',
#        'T_144', 'T_151', 'T_154', 'T_156', 'T_168', 'T_17', 'T_177', 'T_18',
#        'T_19', 'T_199', 'T_204', 'T_206', 'T_210', 'T_215', 'T_217', 'T_218',
#        'T_22', 'T_222', 'T_232', 'T_235', 'T_240', 'T_245', 'T_246', 'T_247',
#        'T_251', 'T_258', 'T_30', 'T_34', 'T_36', 'T_39', 'T_44', 'T_51',
#        'T_53', 'T_54', 'T_56', 'T_62', 'T_66', 'T_67', 'T_7', 'T_71', 'T_82',
#        'T_83', 'T_92', 'T_98'],
#       dtype='object')

# %% [markdown]
# And we also support the final_reconstruction attribute that returns the same datastructure as the input data, but switches the actual data with the translated reconstruction (for the translted modality, the rest is the same as the input data)

# %%
final_rec = r.final_reconstruction.datasets["img.IMG"]
inputimg = xmodalix.result.datasets.test.datasets["img.IMG"]

# %% [markdown]
# ## Vis 2D aligned latent development

# %%
## from old autoecodix framework
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

def plot_translate_latent(
    # cfg, -> removed
    embedding,
    color_param,
    style_param=None,
    save_fig="",
):
    """
    Creates a 2D visualization of the 2D embedding of the latent space.
    ARGS:
        cfg (dict): config dictionary
        embedding (pd.DataFrame): embedding on which is visualized. Assumes prior 2D dimension reduction.
        color_param (str): Clinical parameter to color scatter plot
        style_param (str): Parameter e.g. "Translate" to facet scatter plot
        save_fig (str): File path for saving the plot. Use appropriate file
                        endings to specify image type (e.g. '*.png')
    RETURNS:
        fig (seaborn.FacetGrid): Figure handle

    """
    labels = embedding[color_param]
    # logger = getlogger(cfg)
    numeric = False
    if not (type(labels[0]) is str):
        if len(np.unique(labels)) > 3:
            # if not cfg["PLOT_NUMERIC"]:
            # print(
            #     f"The provided label column is numeric and converted to categories."
            # )
            # labels = pd.qcut(
            #     labels, q=4, labels=["1stQ", "2ndQ", "3rdQ", "4thQ"]
            # ).astype(str)
            # else:
            numeric = True
        else:
            labels = [str(x) for x in labels]

    # check if label or embedding is longerm and duplicate the shorter one
    if len(labels) < embedding.shape[0]:
        print(
            "Given labels do not have the same length as given sample size. Labels will be duplicated."
        )
        labels = [
            label for label in labels for _ in range(embedding.shape[0] // len(labels))
        ]
    elif len(labels) > embedding.shape[0]:
        labels = list(set(labels))

    if not style_param == None:
        embedding[color_param] = labels
        if numeric:
            palette = "bwr"
        else:
            palette = None
        plot = sns.relplot(
            data=embedding,
            x="DIM1",
            y="DIM2",
            hue=color_param,
            palette=palette,
            col=style_param,
            style=style_param,
            markers=True,
            alpha=0.4,
            ec="black",
            height=10,
            aspect=1,
            s=150,
        )

    if len(save_fig) > 0:
        plot.savefig(save_fig, bbox_inches="tight")

    return plot

# %%
## Collect all metadata and latent spaces from datasets
clin_data = []
latent_data = []

for split in ["train", "test", "valid"]:
	split_ds = getattr(r.datasets, split, None)
	if split_ds is not None:
		for key, ds in split_ds.datasets.items():
			df_latent = r.get_latent_df(epoch=-1, split=split, modality=key)
			df_latent["modality"] = key
			df_latent["sample_ids"] = df_latent.index # Each sample can occur multiple times in latent space
			latent_data.append(df_latent)
			if hasattr(ds, "metadata") and ds.metadata is not None:
				df = ds.metadata.copy()
				# Add sample_ids as a column if it's the index
				if df.index.name == "sample_ids" and "sample_ids" not in df.columns:
					print(key)
					print(df)
					df = df.reset_index()
				df["split"] = split
				df["modality"] = key
				clin_data.append(df)

if latent_data and clin_data:
	latent_data = pd.concat(latent_data, axis=0, ignore_index=True)
	clin_data = pd.concat(clin_data, axis=0, ignore_index=True)
	if "sample_ids" in clin_data.columns:
		clin_data = clin_data.drop_duplicates(subset="sample_ids").set_index("sample_ids")
else:
	latent_data = pd.DataFrame()
	clin_data = pd.DataFrame()
# Out:
# img.IMG
#                         img_paths  extra_class_labels early
# sample_ids
# T_32         ALY-2_SYS721_t32.tif                  32   '1'
# T_114       ALY-2_SYS721_t114.tif                 114   '0'
# T_100       ALY-2_SYS721_t100.tif                 100   '0'
# T_26         ALY-2_SYS721_t26.tif                  26   '1'
# T_129       ALY-2_SYS721_t129.tif                 129   '0'
# ...                           ...                 ...   ...
# T_252       ALY-2_SYS721_t252.tif                 252   '0'
# T_253       ALY-2_SYS721_t253.tif                 253   '0'
# T_125       ALY-2_SYS721_t125.tif                 125   '0'
# T_131       ALY-2_SYS721_t131.tif                 131   '0'
# T_119       ALY-2_SYS721_t119.tif                 119   '0'
#
# [182 rows x 3 columns]
# img.IMG
#                         img_paths  extra_class_labels early
# sample_ids
# T_101       ALY-2_SYS721_t101.tif                 101   '0'
# T_115       ALY-2_SYS721_t115.tif                 115   '0'
# T_19         ALY-2_SYS721_t19.tif                  19   '1'
# T_18         ALY-2_SYS721_t18.tif                  18   '1'
# T_30         ALY-2_SYS721_t30.tif                  30   '1'
# T_34         ALY-2_SYS721_t34.tif                  34   '1'
# T_258       ALY-2_SYS721_t258.tif                 258   '0'
# T_22         ALY-2_SYS721_t22.tif                  22   '1'
# T_36         ALY-2_SYS721_t36.tif                  36   '1'
# T_177       ALY-2_SYS721_t177.tif                 177   '0'
# T_51         ALY-2_SYS721_t51.tif                  51   '0'
# T_92         ALY-2_SYS721_t92.tif                  92   '0'
# T_215       ALY-2_SYS721_t215.tif                 215   '0'
# T_44         ALY-2_SYS721_t44.tif                  44   '0'
# T_217       ALY-2_SYS721_t217.tif                 217   '0'
# T_53         ALY-2_SYS721_t53.tif                  53   '0'
# T_206       ALY-2_SYS721_t206.tif                 206   '0'
# T_56         ALY-2_SYS721_t56.tif                  56   '0'
# T_54         ALY-2_SYS721_t54.tif                  54   '0'
# T_199       ALY-2_SYS721_t199.tif                 199   '0'
# T_83         ALY-2_SYS721_t83.tif                  83   '0'
# T_204       ALY-2_SYS721_t204.tif                 204   '0'
# T_210       ALY-2_SYS721_t210.tif                 210   '0'
# T_82         ALY-2_SYS721_t82.tif                  82   '0'
# T_156       ALY-2_SYS721_t156.tif                 156   '0'
# T_142       ALY-2_SYS721_t142.tif                 142   '0'
# T_235       ALY-2_SYS721_t235.tif                 235   '0'
# T_143       ALY-2_SYS721_t143.tif                 143   '0'
# T_7           ALY-2_SYS721_t7.tif                   7   '1'
# T_71         ALY-2_SYS721_t71.tif                  71   '0'
# T_67         ALY-2_SYS721_t67.tif                  67   '0'
# T_98         ALY-2_SYS721_t98.tif                  98   '0'
# T_222       ALY-2_SYS721_t222.tif                 222   '0'
# T_168       ALY-2_SYS721_t168.tif                 168   '0'
# T_154       ALY-2_SYS721_t154.tif                 154   '0'
# T_66         ALY-2_SYS721_t66.tif                  66   '0'
# T_62         ALY-2_SYS721_t62.tif                  62   '0'
# T_144       ALY-2_SYS721_t144.tif                 144   '0'
# T_232       ALY-2_SYS721_t232.tif                 232   '0'
# T_151       ALY-2_SYS721_t151.tif                 151   '0'
# T_218       ALY-2_SYS721_t218.tif                 218   '0'
# T_136       ALY-2_SYS721_t136.tif                 136   '0'
# T_10         ALY-2_SYS721_t10.tif                  10   '1'
# T_240       ALY-2_SYS721_t240.tif                 240   '0'
# T_39         ALY-2_SYS721_t39.tif                  39   '1'
# T_127       ALY-2_SYS721_t127.tif                 127   '0'
# T_251       ALY-2_SYS721_t251.tif                 251   '0'
# T_245       ALY-2_SYS721_t245.tif                 245   '0'
# T_124       ALY-2_SYS721_t124.tif                 124   '0'
# T_246       ALY-2_SYS721_t246.tif                 246   '0'
# T_247       ALY-2_SYS721_t247.tif                 247   '0'
# T_17         ALY-2_SYS721_t17.tif                  17   '1'
# img.IMG
#                         img_paths  extra_class_labels early
# sample_ids
# T_128       ALY-2_SYS721_t128.tif                 128   '0'
# T_117       ALY-2_SYS721_t117.tif                 117   '0'
# T_31         ALY-2_SYS721_t31.tif                  31   '1'
# T_248       ALY-2_SYS721_t248.tif                 248   '0'
# T_24         ALY-2_SYS721_t24.tif                  24   '1'
# T_259       ALY-2_SYS721_t259.tif                 259   '0'
# T_105       ALY-2_SYS721_t105.tif                 105   '0'
# T_79         ALY-2_SYS721_t79.tif                  79   '0'
# T_228       ALY-2_SYS721_t228.tif                 228   '0'
# T_91         ALY-2_SYS721_t91.tif                  91   '0'
# T_159       ALY-2_SYS721_t159.tif                 159   '0'
# T_95         ALY-2_SYS721_t95.tif                  95   '0'
# T_8           ALY-2_SYS721_t8.tif                   8   '1'
# T_173       ALY-2_SYS721_t173.tif                 173   '0'
# T_6           ALY-2_SYS721_t6.tif                   6   '1'
# T_157       ALY-2_SYS721_t157.tif                 157   '0'
# T_141       ALY-2_SYS721_t141.tif                 141   '0'
# T_182       ALY-2_SYS721_t182.tif                 182   '0'
# T_147       ALY-2_SYS721_t147.tif                 147   '0'
# T_152       ALY-2_SYS721_t152.tif                 152   '0'
# T_135       ALY-2_SYS721_t135.tif                 135   '0'
# T_108       ALY-2_SYS721_t108.tif                 108   '0'
# T_254       ALY-2_SYS721_t254.tif                 254   '0'
# T_255       ALY-2_SYS721_t255.tif                 255   '0'
# T_15         ALY-2_SYS721_t15.tif                  15   '1'
# T_130       ALY-2_SYS721_t130.tif                 130   '0'

# %%
from umap import UMAP

## Make 2D Embedding with UMAP
if latent_data.drop(columns=["sample_ids", "modality"]).shape[1] > 2:
	reducer = UMAP(n_components=2)
	embedding = pd.DataFrame(reducer.fit_transform(latent_data.drop(columns=["sample_ids", "modality"])))
	embedding.columns = ["DIM1", "DIM2"]
	embedding["sample_ids"] = latent_data["sample_ids"]
	embedding["modality"] = latent_data["modality"]
else:
	embedding = latent_data

# Merge with clinical data via sample_ids
embedding = embedding.merge(clin_data.drop(columns=["modality"]), on="sample_ids", how="left")

embedding
# Out:
# /Users/maximilianjoas/development/autoencodix_package/.venv/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
#           DIM1      DIM2 sample_ids        modality              img_paths  \
# 0     8.198257  0.636473        T_1  multi_bulk.RNA    ALY-2_SYS721_t1.tif
# 1     8.627654 -1.144808      T_100  multi_bulk.RNA  ALY-2_SYS721_t100.tif
# 2    11.679051  0.884740      T_102  multi_bulk.RNA  ALY-2_SYS721_t102.tif
# 3     9.770250 -1.568487      T_103  multi_bulk.RNA  ALY-2_SYS721_t103.tif
# 4     8.075805 -0.022201      T_104  multi_bulk.RNA  ALY-2_SYS721_t104.tif
# ..         ...       ...        ...             ...                    ...
# 775   4.574798  2.857745        T_6         img.IMG    ALY-2_SYS721_t6.tif
# 776   5.990785  2.300943       T_79         img.IMG   ALY-2_SYS721_t79.tif
# 777   7.441862  2.696359        T_8         img.IMG    ALY-2_SYS721_t8.tif
# 778   8.174600  2.528135       T_91         img.IMG   ALY-2_SYS721_t91.tif
# 779   6.844770  0.964765       T_95         img.IMG   ALY-2_SYS721_t95.tif
#
#      extra_class_labels early  split
# 0                     1   '1'  train
# 1                   100   '0'  train
# 2                   102   '0'  train
# 3                   103   '0'  train
# 4                   104   '0'  train
# ..                  ...   ...    ...
# 775                   6   '1'  valid
# 776                  79   '0'  valid
# 777                   8   '1'  valid
# 778                  91   '0'  valid
# 779                  95   '0'  valid
#
# [780 rows x 8 columns]

# %%
param = "extra_class_labels"
sns.set_theme(font_scale=2)
sns.set_style("white")

plot = plot_translate_latent(
	embedding=embedding,
	color_param=param,
	style_param="modality",
)

# %%
latent_data
# Out:
#      LatDim_0  LatDim_1  LatDim_2  LatDim_3  LatDim_4  LatDim_5  LatDim_6  \
# 0    1.414400  1.416510  2.044666 -0.108115 -0.092842  0.085212 -0.358094
# 1   -0.247118  0.972212 -0.363582  0.064597 -0.859391  1.354291 -1.219108
# 2    1.284891 -2.187709  1.572996 -0.135578  1.096774 -1.026363  0.645953
# 3   -0.745494 -0.331092  1.280092  0.750884 -0.562339  2.638144 -0.246400
# 4   -0.306313  0.987168  1.232323  0.954059 -1.052114 -0.521583 -1.271333
# ..        ...       ...       ...       ...       ...       ...       ...
# 775 -1.378061  6.687994 -1.558168 -0.597816 -0.107062  1.999785  0.761971
# 776 -0.385474  2.877133  0.690203 -0.395103  0.441787  3.199653  1.322672
# 777  1.418240  3.027368 -0.954062 -0.843282  0.216785  2.158576 -0.394915
# 778  0.040878  2.507204  0.101710 -1.640338  0.696568  1.551807  1.284727
# 779  0.533325  3.566370 -0.020717 -0.049500 -0.181998 -0.797728 -0.989661
#
#      LatDim_7        modality sample_ids
# 0   -0.070777  multi_bulk.RNA        T_1
# 1   -1.071154  multi_bulk.RNA      T_100
# 2    1.092595  multi_bulk.RNA      T_102
# 3   -0.607216  multi_bulk.RNA      T_103
# 4    1.227892  multi_bulk.RNA      T_104
# ..        ...             ...        ...
# 775 -2.937611         img.IMG        T_6
# 776 -1.655697         img.IMG       T_79
# 777  1.516456         img.IMG        T_8
# 778  1.089189         img.IMG       T_91
# 779  0.330044         img.IMG       T_95
#
# [780 rows x 10 columns]

# %% [markdown]
# ### Flexible Prediction
# We train the Xmodalix with multiple data modalities, out of all these modalities, we can build any pair for translation byt passing the keys (as defined in your config or datapackage) to the predict method like:

# %%
result2 = xmodalix.predict(from_key="IMG", to_key="IMG")
# Out:
# Prediction complete.
# Processing latent space results into a single AnnData object...
# Identified source modality for latent space: 'multi_bulk.RNA'
#   - Added 279 source feature IDs to .uns
# Finished processing latent results.

# %% [markdown]
# ### Inspecting losses
# We save all losses in our result object, see the keys here:

# %%
result.sub_losses.keys()
# Out:
# dict_keys(['total_loss', 'adver_loss', 'aggregated_sub_losses', 'paired_loss', 'class_loss', 'multi_bulk.RNA.recon_loss', 'multi_bulk.RNA.var_loss', 'multi_bulk.RNA.anneal_factor', 'multi_bulk.RNA.effective_beta_factor', 'multi_bulk.RNA.loss', 'multi_bulk.RNA2.recon_loss', 'multi_bulk.RNA2.var_loss', 'multi_bulk.RNA2.anneal_factor', 'multi_bulk.RNA2.effective_beta_factor', 'multi_bulk.RNA2.loss', 'img.IMG.recon_loss', 'img.IMG.var_loss', 'img.IMG.anneal_factor', 'img.IMG.effective_beta_factor', 'img.IMG.loss', 'clf_loss'])

# %% [markdown]
# After selecting a subloss, this works like a standard TrainingDynamic

# %%
result.sub_losses.get("adver_loss")
# Out:
# TrainingDynamics()

# %% [markdown]
# ### Visualizing a sample output
# Note this is shown with only one epoch training, I've seen good results for 20 epochs of pretraining img and 30 epochs of normal training

# %%
img = result.reconstructions.get(split="test", epoch=-1)

# %%
img = img["translation"]

# %%
img.shape
# Out:
# (52, 1, 64, 64)

# %%
sample_img = img[0, :, :, :].squeeze()
sample_img.shape
# Out:
# (64, 64)

# %%
sample_img.max()
# Out:
# np.float32(0.7483821)

# %%
import matplotlib.pyplot as plt
plt.imshow(sample_img)

# %% [markdown]
# ### Getting Info about pretraining
# The pretraining is saved in sub_results in the result object

# %%
sub_res = result.sub_results
sub_res
# Out:
# {'multi_bulk.RNA': None,
#  'multi_bulk.RNA2': None,
#  'img.IMG': None,
#  'pretrain.img.IMG': Result Object Public Attributes:
#  ------------------------------
#  latentspaces: TrainingDynamics object
#  sample_ids: TrainingDynamics object
#  reconstructions: TrainingDynamics object
#  mus: TrainingDynamics object
#  sigmas: TrainingDynamics object
#  losses: TrainingDynamics object
#  sub_losses: LossRegistry(_losses={'recon_loss': TrainingDynamics(), 'var_loss': TrainingDynamics(), 'anneal_factor': TrainingDynamics(), 'effective_beta_factor': TrainingDynamics()})
#  preprocessed_data: Tensor of shape (0,)
#  model: ImageVAEArchitecture
#  model_checkpoints: TrainingDynamics object
#  datasets: DatasetContainer(train=None, valid=None, test=None)
#  new_datasets: DatasetContainer(train=None, valid=None, test=None)
#  adata_latent: AnnData object with n_obs × n_vars = 0 × 0
#  final_reconstruction: None
#  sub_results: None
#  sub_reconstructions: None
#  embedding_evaluation: Empty DataFrame
#  Columns: []
#  Index: []}

# %% [markdown]
# ## Xmodal_loss Visualization
# Vibe coded provisory loss visualization

# %%
result.sub_losses.keys()
result.sub_losses.get("img.IMG.var_loss").get()
# Out:
# {0: {'train': array(4.95049939e-06), 'valid': array(9.21531521e-07)},
#  1: {'train': array(0.00026957), 'valid': array(8.42495463e-05)},
#  2: {'train': array(0.01300155), 'valid': array(0.00588584)},
#  3: {'train': array(0.09601091), 'valid': array(0.05947901)},
#  4: {'train': array(0.10883159), 'valid': array(0.08378701)}}

# %%
import matplotlib.pyplot as plt


def plot_losses(result):
    """
    Generates and displays plots for all relevant losses from a Result object.

    Args:
        result: Your custom result object containing the sub_losses attribute.
    """
    if not hasattr(result, "sub_losses"):
        print(
            "Error: The provided result object does not have a 'sub_losses' attribute."
        )
        return

    # 1. Get all loss keys and filter out the factors
    all_loss_keys = result.sub_losses.keys()
    keys_to_plot = [key for key in all_loss_keys if not key.endswith("_factor")]

    if not keys_to_plot:
        print("No valid loss keys found to plot.")
        return

    # 2. Iterate through each loss and create a plot
    for loss_name in keys_to_plot:
        try:
            # Retrieve the nested dictionary for the current loss
            loss_data = result.sub_losses.get(loss_name).get()

            # 3. Unpack the data into lists for plotting
            epochs = sorted(loss_data.keys())
            train_losses = [loss_data[epoch]["train"] for epoch in epochs]

            # Check if validation data exists before trying to plot it
            has_valid_data = all("valid" in loss_data[epoch] for epoch in epochs)
            if has_valid_data:
                valid_losses = [loss_data[epoch]["valid"] for epoch in epochs]

            # 4. Create the plot
            plt.figure(figsize=(10, 6))
            plt.plot(epochs, train_losses, "o-", label=f"Train ({loss_name})")
            if has_valid_data:
                plt.plot(epochs, valid_losses, "x-", label=f"Validation ({loss_name})")

            plt.title(f"Training and Validation Loss: {loss_name}")
            plt.xlabel("Epoch")
            plt.ylabel("Loss")
            plt.legend()
            plt.grid(True)
            plt.show()

        except (AttributeError, TypeError, KeyError) as e:
            print(f"Could not plot '{loss_name}'. Error retrieving data: {e}")

# %% [markdown]
# ## Imagix
# If we want to use a standard image vae, we can use the Imagix pipeline. Note that only one image dataset is allowed here
# **NOTE**:
# set the datacase in config to DataCase.IMG_TO_IMG

# %%
import autoencodix as acx
from autoencodix.configs.default_config import (
    DefaultConfig,
    DataConfig,
    DataCase,
    DataInfo,
)
import os

IMGROOT = os.path.join("data/images/ALY-2_SYS721/")
IMGMAPPING = os.path.join("data/ALY-2_SYS721_mappings.txt")
NUMFILE = os.path.join("data/AM3_NO2_raw_cell.tsv")

img_config2 = DefaultConfig(
    data_case=DataCase.IMG_TO_IMG,
    checkpoint_interval=10,
    epochs=40,
    reconstruction_loss="bce",
    beta=0.1,
    scaling="MINMAX",
    anneal_function="logistic-late",
    data_config=DataConfig(
        data_info={
            "IMG": DataInfo(
                file_path=IMGROOT,
				scaling="MINMAX",
                data_type="IMG",
            ),
            "ANNO": DataInfo(
                file_path=IMGMAPPING,
                data_type="ANNOTATION",
            ),
        },
    ),
)

imagix = acx.Imagix(config=img_config2)
imagix.preprocess()
imagix.fit()
# Out:
# Given image size is possible, rescaling images to: 64x64
# Successfully loaded 260 images for IMG
# calling normalize image in _process_ing_to_img_case
# anno key: IMG
# DP:
# annotation:
#   IMG: 260 samples × 3 features
# img:
#   IMG: 260 items
# k: multi_sc
# k: multi_bulk
# k: annotation
# k: img
# k: from_modality
# k: to_modality
# DP:
# annotation:
#   IMG: 260 samples × 3 features
# img:
#   IMG: 260 items
# k: multi_sc
# k: multi_bulk
# k: annotation
# k: img
# k: from_modality
# k: to_modality
# DP:
# annotation:
#   IMG: 260 samples × 3 features
# img:
#   IMG: 260 items
# k: multi_sc
# k: multi_bulk
# k: annotation
# k: img
# k: from_modality
# k: to_modality
# Converting 182 images to torch.float32 tensors...
# Converting 52 images to torch.float32 tensors...
# Converting 26 images to torch.float32 tensors...
# /Users/maximilianjoas/development/autoencodix_package/src/autoencodix/utils/_imgreader.py:264: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support sep=None with delim_whitespace=False; you can avoid this warning by specifying engine='python'.
#   annotation = pd.read_csv(anno_file, sep=sep)
# Epoch 1 - Train Loss: 3589.3995
# Sub-losses: recon_loss: 3588.3148, var_loss: 1.0847, anneal_factor: 0.0000, effective_beta_factor: 0.0000
# Epoch 1 - Valid Loss: 3570.2434
# Sub-losses: recon_loss: 3570.2434, var_loss: 0.0000, anneal_factor: 0.0000, effective_beta_factor: 0.0000
# Epoch 2 - Train Loss: 3502.7752
# Sub-losses: recon_loss: 3497.4251, var_loss: 5.3501, anneal_factor: 0.0000, effective_beta_factor: 0.0000
# Epoch 2 - Valid Loss: 3509.9441
# Sub-losses: recon_loss: 3509.9441, var_loss: 0.0000, anneal_factor: 0.0000, effective_beta_factor: 0.0000
# Epoch 3 - Train Loss: 3443.4710
# Sub-losses: recon_loss: 3433.2121, var_loss: 10.2588, anneal_factor: 0.0000, effective_beta_factor: 0.0000
# Epoch 3 - Valid Loss: 3408.9898
# Sub-losses: recon_loss: 3408.9898, var_loss: 0.0000, anneal_factor: 0.0000, effective_beta_factor: 0.0000
# Epoch 4 - Train Loss: 3398.5922
# Sub-losses: recon_loss: 3380.3907, var_loss: 18.2015, anneal_factor: 0.0000, effective_beta_factor: 0.0000
# Epoch 4 - Valid Loss: 3282.3774
# Sub-losses: recon_loss: 3282.3774, var_loss: 0.0000, anneal_factor: 0.0000, effective_beta_factor: 0.0000
# Epoch 5 - Train Loss: 3365.3373
# Sub-losses: recon_loss: 3335.1484, var_loss: 30.1889, anneal_factor: 0.0000, effective_beta_factor: 0.0000
# Epoch 5 - Valid Loss: 3167.0358
# Sub-losses: recon_loss: 3167.0144, var_loss: 0.0212, anneal_factor: 0.0000, effective_beta_factor: 0.0000
# Epoch
anneal_factor: 0.0025, effective_beta_factor: 0.0002
# Epoch 20 - Train Loss: 2912.9922
# Sub-losses: recon_loss: 2912.6582, var_loss: 0.3341, anneal_factor: 0.0041, effective_beta_factor: 0.0004
# Epoch 20 - Valid Loss: 2938.0589
# Sub-losses: recon_loss: 2937.1845, var_loss: 0.8743, anneal_factor: 0.0041, effective_beta_factor: 0.0004
# Epoch 21 - Train Loss: 2904.3591
# Sub-losses: recon_loss: 2903.9436, var_loss: 0.4154, anneal_factor: 0.0067, effective_beta_factor: 0.0007
# Epoch 21 - Valid Loss: 2920.8489
# Sub-losses: recon_loss: 2919.9183, var_loss: 0.9307, anneal_factor: 0.0067, effective_beta_factor: 0.0007
# Epoch 22 - Train Loss: 2895.8180
# Sub-losses: recon_loss: 2895.5254, var_loss: 0.2926, anneal_factor: 0.0110, effective_beta_factor: 0.0011
# Epoch 22 - Valid Loss: 2906.4066
# Sub-losses: recon_loss: 2906.0541, var_loss: 0.3525, anneal_factor: 0.0110, effective_beta_factor: 0.0011
# Epoch 23 - Train Loss: 2888.7388
# Sub-losses: recon_loss: 2888.4351, var_loss: 0.3037, anneal_factor: 0.0180, effective_beta_factor: 0.0018
# Epoch 23 - Valid Loss: 2896.3534
# Sub-losses: recon_loss: 2896.1064, var_loss: 0.2471, anneal_factor: 0.0180, effective_beta_factor: 0.0018
# Epoch 24 - Train Loss: 2883.1118
# Sub-losses: recon_loss: 2882.8171, var_loss: 0.2947, anneal_factor: 0.0293, effective_beta_factor: 0.0029
# Epoch 24 - Valid Loss: 2886.2272
# Sub-losses: recon_loss: 2885.9038, var_loss: 0.3233, anneal_factor: 0.0293, effective_beta_factor: 0.0029
# Epoch 25 - Train Loss: 2878.2728
# Sub-losses: recon_loss: 2877.8638, var_loss: 0.4089, anneal_factor: 0.0474, effective_beta_factor: 0.0047
# Epoch 25 - Valid Loss: 2878.6980
# Sub-losses: recon_loss: 2878.2882, var_loss: 0.4100, anneal_factor: 0.0474, effective_beta_factor: 0.0047
# Epoch 26 - Train Loss: 2874.6605
# Sub-losses: recon_loss: 2874.1669, var_loss: 0.4937, anneal_factor: 0.0759, effective_beta_factor: 0.0076
# Epoch 26 - Valid Loss: 2872.9354
# Sub-losses: recon_loss: 2872.5132, var_loss: 0.4222, anneal_factor: 0.0759, effective_beta_factor: 0.0076
# Epoch 27 - Train Loss: 2870.5352
# Sub-losses: recon_loss: 2869.9821, var_loss: 0.5531, anneal_factor: 0.1192, effective_beta_factor: 0.0119
# Epoch 27 - Valid Loss: 2868.8891
# Sub-losses: recon_loss: 2868.4020, var_loss: 0.4871, anneal_factor: 0.1192, effective_beta_factor: 0.0119
# Epoch 28 - Train Loss: 2867.7756
# Sub-losses: recon_loss: 2867.0928, var_loss: 0.6828, anneal_factor: 0.1824, effective_beta_factor: 0.0182
# Epoch 28 - Valid Loss: 2865.6112
# Sub-losses: recon_loss: 2865.0607, var_loss: 0.5505, anneal_factor: 0.1824, effective_beta_factor: 0.0182
# Epoch 29 - Train Loss: 2865.4887
# Sub-losses: recon_loss: 2864.7709, var_loss: 0.7178, anneal_factor: 0.2689, effective_beta_factor: 0.0269
# Epoch 29 - Valid Loss: 2862.2882
# Sub-losses: recon_loss: 2861.8624, var_loss: 0.4258, anneal_factor: 0.2689, effective_beta_factor: 0.0269
# Epoch 30 - Train Loss: 2863.2909
# Sub-losses: recon_loss: 2862.6202, var_loss: 0.6707, anneal_factor: 0.3775, effective_beta_factor: 0.0378
# Epoch 30 - Valid Loss: 2860.4618
# Sub-losses: recon_loss: 2859.8735, var_loss: 0.5884, anneal_factor: 0.3775, effective_beta_factor: 0.0378
# Epoch 31 - Train Loss: 2861.0526
# Sub-losses: recon_loss: 2860.3149, var_loss: 0.7377, anneal_factor: 0.5000, effective_beta_factor: 0.0500
# Epoch 31 - Valid Loss: 2858.8398
# Sub-losses: recon_loss: 2858.4760, var_loss: 0.3639, anneal_factor: 0.5000, effective_beta_factor: 0.0500
# Epoch 32 - Train Loss: 2859.4453
# Sub-losses: recon_loss: 2858.7886, var_loss: 0.6567, anneal_factor: 0.6225, effective_beta_factor: 0.0622
# Epoch 32 - Valid Loss: 2857.3627
# Sub-losses: recon_loss: 2856.6202, var_loss: 0.7425, anneal_factor: 0.6225, effective_beta_factor: 0.0622
# Epoch 33 - Train Loss: 2858.4319
# Sub-losses: recon_loss: 2857.5430, var_loss: 0.8889, anneal_factor: 0.7311, effective_beta_factor: 0.0731
# Epoch 33 - Valid Loss: 2855.5282
# Sub-losses: recon_loss: 2854.7620, var_loss: 0.7661, anneal_factor: 0.7311, effective_beta_factor: 0.0731
# Epoch 34 - Train Loss: 2857.1240
# Sub-losses: recon_loss: 2856.2808, var_loss: 0.8432, anneal_factor: 0.8176, effective_beta_factor: 0.0818
# Epoch 34 - Valid Loss: 2854.5688
# Sub-losses: recon_loss: 2853.8909, var_loss: 0.6780, anneal_factor: 0.8176, effective_beta_factor: 0.0818
# Epoch 35 - Train Loss: 2855.2633
# Sub-losses: recon_loss: 2854.5014, var_loss: 0.7619, anneal_factor: 0.8808, effective_beta_factor: 0.0881
# Epoch 35 - Valid Loss: 2854.8074
# Sub-losses: recon_loss: 2853.5739, var_loss: 1.2334, anneal_factor: 0.8808, effective_beta_factor: 0.0881
# Epoch 36 - Train Loss: 2854.4653
# Sub-losses: recon_loss: 2853.5950, var_loss: 0.8704, anneal_factor: 0.9241, effective_beta_factor: 0.0924
# Epoch 36 - Valid Loss: 2851.9874
# Sub-losses: recon_loss: 2851.3191, var_loss: 0.6683, anneal_factor: 0.9241, effective_beta_factor: 0.0924
# Epoch 37 - Train Loss: 2853.4427
# Sub-losses: recon_loss: 2852.7913, var_loss: 0.6513, anneal_factor: 0.9526, effective_beta_factor: 0.0953
# Epoch 37 - Valid Loss: 2852.2359
# Sub-losses: recon_loss: 2851.1911, var_loss: 1.0448, anneal_factor: 0.9526, effective_beta_factor: 0.0953
# Epoch 38 - Train Loss: 2852.3881
# Sub-losses: recon_loss: 2851.6578, var_loss: 0.7303, anneal_factor: 0.9707, effective_beta_factor: 0.0971
# Epoch 38 - Valid Loss: 2850.3492
# Sub-losses: recon_loss: 2849.8347, var_loss: 0.5145, anneal_factor: 0.9707, effective_beta_factor: 0.0971
# Epoch 39 - Train Loss: 2851.4800
# Sub-losses: recon_loss: 2850.9003, var_loss: 0.5798, anneal_factor: 0.9820, effective_beta_factor: 0.0982
# Epoch 39 - Valid Loss: 2851.8993
# Sub-losses: recon_loss: 2850.5102, var_loss: 1.3892, anneal_factor: 0.9820, effective_beta_factor: 0.0982
# Epoch 40 - Train Loss: 2850.7151
# Sub-losses: recon_loss: 2849.7850, var_loss: 0.9301, anneal_factor: 0.9890, effective_beta_factor: 0.0989
# Epoch 40 - Valid Loss: 2849.9056
# Sub-losses: recon_loss: 2848.9453, var_loss: 0.9604, anneal_factor: 0.9890, effective_beta_factor: 0.0989

# %%
imagix.config.data_case
# Out:
# <DataCase.IMG_TO_IMG: 'IMG<->IMG'>

# %%
imagix.predict()
# Out:
# Result Object Public Attributes:
# ------------------------------
# latentspaces: TrainingDynamics object
# sample_ids: TrainingDynamics object
# reconstructions: TrainingDynamics object
# mus: TrainingDynamics object
# sigmas: TrainingDynamics object
# losses: TrainingDynamics object
# sub_losses: LossRegistry(_losses={'recon_loss': TrainingDynamics(), 'var_loss': TrainingDynamics(), 'anneal_factor': TrainingDynamics(), 'effective_beta_factor': TrainingDynamics()})
# preprocessed_data: Tensor of shape (0,)
# model: ImageVAEArchitecture
# model_checkpoints: TrainingDynamics object
# datasets: DatasetContainer(train=<autoencodix.data._image_dataset.ImageDataset object at 0x33b9f8af0>, valid=<autoencodix.data._image_dataset.ImageDataset object at 0x348e80910>, test=<autoencodix.data._image_dataset.ImageDataset object at 0x348e823b0>)
# new_datasets: DatasetContainer(train=None, valid=None, test=None)
# adata_latent: AnnData object with n_obs × n_vars = 52 × 16
#     uns: 'var_names'
# final_reconstruction: <autoencodix.data._image_dataset.ImageDataset object at 0x348e81ae0>
# sub_results: None
# sub_reconstructions: None
# embedding_evaluation: Empty DataFrame
# Columns: []
# Index: []

# %%
import matplotlib.pyplot as plt
r2 = imagix.result
r2.final_reconstruction
sample_img = r2.final_reconstruction.data[17, :, :, :]
sample_img = sample_img.squeeze()

plt.imshow(sample_img, cmap="grey")

# %%
sample_img
# Out:
# tensor([[0.1044, 0.0181, 0.0300,  ..., 0.0166, 0.0156, 0.0798],
#         [0.0121, 0.0032, 0.0026,  ..., 0.0041, 0.0015, 0.0201],
#         [0.0197, 0.0058, 0.0041,  ..., 0.0070, 0.0021, 0.0434],
#         ...,
#         [0.0293, 0.0084, 0.0067,  ..., 0.0108, 0.0019, 0.0160],
#         [0.0107, 0.0044, 0.0039,  ..., 0.0056, 0.0036, 0.0408],
#         [0.0910, 0.0128, 0.0141,  ..., 0.0159, 0.0206, 0.0520]])

# %%
sample_img = r2.reconstructions.get(split="test", epoch=-1)
sample_img = sample_img[0,:,:,:]
sample_img = sample_img.squeeze()
sample_img.shape
# Out:
# (64, 64)

# %%
import matplotlib.pyplot as plt

plt.imshow(sample_img, cmap="grey")

# %%
plot_losses(r2)

# %%
imagix._datasets.train.data[0]
# Out:
# tensor([[[1.0000e-01, 1.0000e-01, 1.0000e-01,  ..., 1.0000e-01,
#           7.5000e-02, 5.0000e-02],
#          [1.0000e-01, 1.0000e-01, 7.5000e-02,  ..., 5.0000e-02,
#           7.5000e-02, 2.5000e-02],
#          [7.5000e-02, 7.5000e-02, 7.5000e-02,  ..., 7.5000e-02,
#           5.0000e-02, 5.0000e-02],
#          ...,
#          [2.5000e-02, 2.5000e-02, 5.0000e-02,  ..., 2.5000e-02,
#           2.5000e-02, 1.8626e-09],
#          [2.5000e-02, 2.5000e-02, 2.5000e-02,  ..., 1.8626e-09,
#           2.5000e-02, 2.5000e-02],
#          [5.0000e-02, 2.5000e-02, 2.5000e-02,  ..., 1.8626e-09,
#           2.5000e-02, 2.5000e-02]]])

# %%
loader = imagix._trainer._trainloader
for batch in loader:
    a = batch
    break

# %%
type(a)
# Out:
# list

# %% [markdown]
# a

# %%
len(a)
# Out:
# 3

# %%
a[1].max()
# Out:
# tensor(1., device='mps:0')
