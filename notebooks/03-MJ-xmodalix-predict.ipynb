# %% [markdown]
# ## XModalix Workbook

# %% [markdown]
# #### IMPORTS

# %%
import os
from autoencodix.configs.default_config import DataConfig, DataInfo, DefaultConfig
from autoencodix.configs.xmodalix_config import XModalixConfig
import autoencodix as acx

notebook_dir = os.path.dirname(os.path.abspath("__file__"))
print(notebook_dir)
os.chdir(notebook_dir)
os.chdir("..")
print(os.getcwd())
# Out:
# /Users/maximilianjoas/development/autoencodix_package/notebooks
# /Users/maximilianjoas/development/autoencodix_package

# %% [markdown]
# #### GLOBALS
# **ATTENTION**
# Be sure to have the appropriate files, or adjust paths and make your own config

# %%
IMGROOT = os.path.join("data/images/ALY-2_SYS721/")
IMGMAPPING = os.path.join("data/ALY-2_SYS721_mappings.txt")
NUMFILE = os.path.join("data/AM3_NO2_raw_cell.tsv")

img_config = DefaultConfig(
    checkpoint_interval=25,
	loss_reduction = "sum",
    class_param="early",
    epochs=5,
	beta = 0.01,
    requires_paired=False,
	gamma= 2,
	delta_class= 0.0,
	delta_pair = 3,
	learning_rate=0.001,
	k_filter=1000,
	latent_dim=8,
    batch_size=181,
    # blablabla="",
    data_config=DataConfig(
        data_info={
            "IMG": DataInfo(
                file_path=IMGROOT,
                data_type="IMG",
				scaling="MINMAX",
                translate_direction="to",
                pretrain_epochs=30
            ),
            "RNA": DataInfo(
                file_path=NUMFILE,
                data_type="NUMERIC",
				scaling = "MINMAX",
                translate_direction="from",
            ),
            "RNA2": DataInfo(
                file_path=NUMFILE,
                data_type="NUMERIC",
            ),
            "ANNO": DataInfo(
                file_path=IMGMAPPING,
                data_type="ANNOTATION",
            ),
        },
    ),
)

# %% [markdown]
# ### Run Xmodalix with defined config
# - .run() does not work yet, because we dont have a visualizer, so we run it step by step

# %%
# %env CUBLAS_WORKSPACE_CONFIG=:16:8
# Out:
# env: CUBLAS_WORKSPACE_CONFIG=:16:8

# %%
xmodalix = acx.XModalix(config=img_config)
xmodalix.preprocess()
xmodalix.fit()
result = xmodalix.predict()
# Out:
# Given image size is possible, rescaling images to: 64x64
# Successfully loaded 260 images for IMG
# anno key: RNA
# anno key: RNA2
# anno key: IMG
# DP:
# multi_bulk:
#   RNA: 260 samples × 279 features
#   RNA2: 260 samples × 279 features
# annotation:
#   RNA: 260 samples × 3 features
#   RNA2: 260 samples × 3 features
#   IMG: 260 samples × 3 features
# img:
#   IMG: 260 items
# k: multi_sc
# k: multi_bulk
# k: annotation
# k: img
# k: from_modality
# k: to_modality
# DP:
# multi_bulk:
#   RNA: 260 samples × 279 features
#   RNA2: 260 samples × 279 features
# annotation:
#   RNA: 260 samples × 3 features
#   RNA2: 260 samples × 3 features
#   IMG: 260 samples × 3 features
# img:
#   IMG: 260 items
# k: multi_sc
# k: multi_bulk
# k: annotation
# k: img
# k: from_modality
# k: to_modality
# DP:
# multi_bulk:
#   RNA: 260 samples × 279 features
#   RNA2: 260 samples × 279 features
# annotation:
#   RNA: 260 samples × 3 features
#   RNA2: 260 samples × 3 features
#   IMG: 260 samples × 3 features
# img:
#   IMG: 260 items
# k: multi_sc
# k: multi_bulk
# k: annotation
# k: img
# k: from_modality
# k: to_modality
# /Users/maximilianjoas/development/autoencodix_package/src/autoencodix/base/_base_pipeline.py:189: UserWarning: Your config is of type: <class 'autoencodix.configs.default_config.DefaultConfig'>, for this pipeline the default params of: <class 'autoencodix.configs.xmodalix_config.XModalixConfig'> work best
#   warnings.warn(
# /Users/maximilianjoas/development/autoencodix_package/src/autoencodix/utils/_bulkreader.py:226: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support sep=None with delim_whitespace=False; you can avoid this warning by specifying engine='python'.
#   return pd.read_csv(file_path, sep=sep, index_col=0)
# /Users/maximilianjoas/development/autoencodix_package/src/autoencodix/utils/_bulkreader.py:226: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support sep=None with delim_whitespace=False; you can avoid this warning by specifying engine='python'.
#   return pd.read_csv(file_path, sep=sep, index_col=0)
# /Users/maximilianjoas/development/autoencodix_package/src/autoencodix/utils/_bulkreader.py:226: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support sep=None with delim_whitespace=False; you can avoid this warning by specifying engine='python'.
#   return pd.read_csv(file_path, sep=sep, index_col=0)
# /Users/maximilianjoas/development/autoencodix_package/src/autoencodix/utils/_imgreader.py:264: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support sep=None with delim_whitespace=False; you can avoid this warning by specifying engine='python'.
#   annotation = pd.read_csv(anno_file, sep=sep)
# /Users/maximilianjoas/development/autoencodix_package/src/autoencodix/data/_filter.py:102: UserWarning: WARNING: k is None or greater than number of columns, keeping all features.
#   warnings.warn(
# /Users/maximilianjoas/development/autoencodix_package/src/autoencodix/data/_filter.py:102: UserWarning: WARNING: k is None or greater than number of columns, keeping all features.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 2
#       1 xmodalix = acx.XModalix(config=img_config)
# ----> 2 xmodalix.preprocess()
#       3 xmodalix.fit()
#       4 result = xmodalix.predict()
#
# File ~/development/autoencodix_package/src/autoencodix/base/_base_pipeline.py:437, in BasePipeline.preprocess(self, config, **kwargs)
#     435 self._validate_user_data()
#     436 if self.preprocessed_data is None:
# --> 437     self._datasets = self._preprocessor.preprocess(
#     438         raw_user_data=self.raw_user_data,  # type: ignore
#     439     )
#     440     self.result.datasets = self._datasets
#     441 else:
#
# File ~/development/autoencodix_package/src/autoencodix/data/_xmodal_preprocessor.py:64, in XModalPreprocessor.preprocess(self, raw_user_data, predict_new_data)
#      59         raise TypeError(
#      60             f"expected type of cur_data to be DataPackage, got {type(cur_data)}"
#      61         )
#      62     cur_indices = cur_split.get("indices")
#      63     datasets[split] = MultiModalDataset(
# ---> 64         datasets=self._process_dp(dp=cur_data, indices=cur_indices),
#      65         config=self.config,
#      66     )
#      68 for k, v in self.dataset_dicts.items():
#      69     print(f"key: {k}, type: {type(v)}")
#
# File ~/development/autoencodix_package/src/autoencodix/data/_xmodal_preprocessor.py:113, in XModalPreprocessor._process_dp(self, dp, indices)
#     111     if metadata is None:
#     112         raise ValueError("metadata cannot be None")
# --> 113     metadata_num = metadata.loc[
#     114         data.index
#     115     ]  # needed when we have only one annotation df containing metadata for all modalities
#     116     dataset_dict[k] = NumericDataset(
#     117         data=torch.from_numpy(data.values),
#     118         config=self.config,
#    (...)
#     122         metadata=metadata_num,
#     123     )
#     124 elif dp_key == "img":
#
# File ~/development/autoencodix_package/.venv/lib/python3.10/site-packages/pandas/core/indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/development/autoencodix_package/.venv/lib/python3.10/site-packages/pandas/core/indexing.py:1420, in _LocIndexer._getitem_axis(self, key, axis)
#    1417     if hasattr(key, "ndim") and key.ndim > 1:
#    1418         raise ValueError("Cannot index with multidimensional key")
# -> 1420     return self._getitem_iterable(key, axis=axis)
#    1422 # nested tuple slicing
#    1423 if is_nested_tuple(key, labels):
#
# File ~/development/autoencodix_package/.venv/lib/python3.10/site-packages/pandas/core/indexing.py:1360, in _LocIndexer._getitem_iterable(self, key, axis)
#    1357 self._validate_key(key, axis)
#    1359 # A collection of keys
# -> 1360 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1361 return self.obj._reindex_with_indexers(
#    1362     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1363 )
#
# File ~/development/autoencodix_package/.venv/lib/python3.10/site-packages/pandas/core/indexing.py:1558, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1555 ax = self.obj._get_axis(axis)
#    1556 axis_name = self.obj._get_axis_name(axis)
# -> 1558 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1560 return keyarr, indexer
#
# File ~/development/autoencodix_package/.venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~/development/autoencodix_package/.venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['T_1', 'T_2', 'T_3', 'T_5', 'T_7', 'T_8', 'T_9', 'T_10', 'T_12', 'T_14',\n       ...\n       'T_249', 'T_250', 'T_251', 'T_252', 'T_253', 'T_254', 'T_255', 'T_257',\n       'T_258', 'T_259'],\n      dtype='object', length=182)] are in the [index]"

# %% [markdown]
# ## Getting Translation and Sample Ids for all splits

# %% [markdown]
# #### First select predict_all = True

# %%
result = xmodalix.predict(predict_all=True)
# Out:
# Prediction complete.
# Processing latent space results into a single AnnData object...
# Identified source modality for latent space: 'multi_bulk.RNA'
#   - Added 279 source feature IDs to .uns
# Finished processing latent results.
# Prediction complete.
# Prediction complete.

# %%
test_translation = result.reconstructions.get(epoch=-1, split="test")["translation"]
print("Test prints: ")
print("=" * 50)
print(f" translation shape: {test_translation.shape}") # (n_samples, n_channels, height, width) here (121,1,64,64)
# sample ids are connected to data modalities and splits
test_sample_ids = result.sample_ids.get(epoch=-1, split="test")
print(f"Data modality keys for translation: {test_sample_ids.keys()}")
print(f"First 4 sample ids for translation: {test_sample_ids['translation'][0:4]}")


# this works analogously for train and valid splits
print("\n\nTrain prints: ")
print("=" * 50)
train_translation = result.reconstructions.get(epoch=-1, split="train")["translation"]
print(f" translation shape: {train_translation.shape}")
train_sample_ids = result.sample_ids.get(epoch=-1, split="train")
print(f"Data modality keys for translation: {train_sample_ids.keys()}")
print(f"First 4 sample ids for translation: {train_sample_ids['translation'][0:4]}") # first 4 sample ids of the translation modality


print("\n\nValid prints: ")
print("=" * 50)

valid_translation = result.reconstructions.get(epoch=-1, split="valid")["translation"]
print(f" translation shape: {valid_translation.shape}")
valid_sample_ids = result.sample_ids.get(epoch=-1, split="valid")
print(f"Data modality keys for translation: {valid_sample_ids.keys()}")
print(f"First 4 sample ids for translation: {valid_sample_ids['translation'][0:4]}") # first 4 sample ids of the translation modality
# Out:
# Test prints:
# ==================================================
#  translation shape: (52, 1, 64, 64)
# Data modality keys for translation: dict_keys(['multi_bulk.RNA', 'multi_bulk.RNA2', 'img.IMG', 'translation', 'reference_img.IMG_to_img.IMG'])
# First 4 sample ids for translation: ['T_108' 'T_113' 'T_125' 'T_129']
#
#
# Train prints:
# ==================================================
#  translation shape: (182, 1, 64, 64)
# Data modality keys for translation: dict_keys(['multi_bulk.RNA', 'multi_bulk.RNA2', 'img.IMG', 'translation', 'reference_img.IMG_to_img.IMG'])
# First 4 sample ids for translation: ['T_1' 'T_10' 'T_100' 'T_104']
#
#
# Valid prints:
# ==================================================
#  translation shape: (26, 1, 64, 64)
# Data modality keys for translation: dict_keys(['multi_bulk.RNA', 'multi_bulk.RNA2', 'img.IMG', 'translation', 'reference_img.IMG_to_img.IMG'])
# First 4 sample ids for translation: ['T_101' 'T_102' 'T_103' 'T_131']

# %% [markdown]
# ### Loading and Saving XModalix
# - works like for other pipelines too, can be used to run another predict pairing also

# %%
len(xmodalix._datasets.train.datasets["multi_bulk.RNA"])
# Out:
# 182

# %%
loader = xmodalix._trainer._trainloader
for batch in loader:
    print(batch)
    break
# Out:
# {'multi_bulk.RNA': {'data': tensor([[0.0898, 0.7051, 0.0000,  ..., 0.0000, 0.0000, 0.0021],
#         [0.5352, 0.5139, 0.5868,  ..., 0.5513, 0.1661, 0.3018],
#         [0.1244, 0.1022, 0.2502,  ..., 0.2367, 0.2669, 0.0046],
#         ...,
#         [0.6175, 0.3439, 0.7429,  ..., 0.6898, 0.3085, 0.9012],
#         [0.4599, 0.3095, 0.8696,  ..., 0.8918, 0.3977, 0.8482],
#         [0.6997, 0.4272, 0.9186,  ..., 0.9903, 0.6165, 0.8726]],
#        device='mps:0'), 'metadata':                    img_paths extra_class_labels early
# T_17    ALY-2_SYS721_t17.tif                 17   '1'
# T_147  ALY-2_SYS721_t147.tif                147   '0'
# T_99    ALY-2_SYS721_t99.tif                 99   '0'
# T_197  ALY-2_SYS721_t197.tif                197   '0'
# T_121  ALY-2_SYS721_t121.tif                121   '0'
# ...                      ...                ...   ...
# T_219  ALY-2_SYS721_t219.tif                219   '0'
# T_248  ALY-2_SYS721_t248.tif                248   '0'
# T_206  ALY-2_SYS721_t206.tif                206   '0'
# T_185  ALY-2_SYS721_t185.tif                185   '0'
# T_220  ALY-2_SYS721_t220.tif                220   '0'
#
# [181 rows x 3 columns], 'sample_ids': [np.str_('T_17'), np.str_('T_147'), np.str_('T_99'), np.str_('T_197'), np.str_('T_121'), np.str_('T_138'), np.str_('T_116'), np.str_('T_85'), np.str_('T_59'), np.str_('T_181'), np.str_('T_84'), np.str_('T_40'), np.str_('T_65'), np.str_('T_6'), np.str_('T_184'), np.str_('T_221'), np.str_('T_215'), np.str_('T_130'), np.str_('T_41'), np.str_('T_114'), np.str_('T_165'), np.str_('T_14'), np.str_('T_244'), np.str_('T_207'), np.str_('T_12'), np.str_('T_64'), np.str_('T_69'), np.str_('T_31'), np.str_('T_208'), np.str_('T_20'), np.str_('T_45'), np.str_('T_177'), np.str_('T_218'), np.str_('T_11'), np.str_('T_88'), np.str_('T_188'), np.str_('T_117'), np.str_('T_54'), np.str_('T_171'), np.str_('T_58'), np.str_('T_186'), np.str_('T_23'), np.str_('T_42'), np.str_('T_15'), np.str_('T_140'), np.str_('T_195'), np.str_('T_210'), np.str_('T_201'), np.str_('T_234'), np.str_('T_46'), np.str_('T_196'), np.str_('T_239'), np.str_('T_212'), np.str_('T_4'), np.str_('T_124'), np.str_('T_143'), np.str_('T_56'), np.str_('T_120'), np.str_('T_255'), np.str_('T_182'), np.str_('T_249'), np.str_('T_172'), np.str_('T_25'), np.str_('T_151'), np.str_('T_252'), np.str_('T_61'), np.str_('T_82'), np.str_('T_189'), np.str_('T_96'), np.str_('T_97'), np.str_('T_90'), np.str_('T_128'), np.str_('T_139'), np.str_('T_152'), np.str_('T_260'), np.str_('T_118'), np.str_('T_72'), np.str_('T_122'), np.str_('T_175'), np.str_('T_107'), np.str_('T_53'), np.str_('T_155'), np.str_('T_250'), np.str_('T_62'), np.str_('T_225'), np.str_('T_205'), np.str_('T_163'), np.str_('T_157'), np.str_('T_259'), np.str_('T_57'), np.str_('T_190'), np.str_('T_237'), np.str_('T_27'), np.str_('T_123'), np.str_('T_63'), np.str_('T_150'), np.str_('T_133'), np.str_('T_34'), np.str_('T_24'), np.str_('T_80'), np.str_('T_134'), np.str_('T_79'), np.str_('T_233'), np.str_('T_74'), np.str_('T_68'), np.str_('T_126'), np.str_('T_242'), np.str_('T_105'), np.str_('T_153'), np.str_('T_168'), np.str_('T_112'), np.str_('T_187'), np.str_('T_213'), np.str_('T_256'), np.str_('T_127'), np.str_('T_214'), np.str_('T_47'), np.str_('T_18'), np.str_('T_145'), np.str_('T_86'), np.str_('T_141'), np.str_('T_243'), np.str_('T_106'), np.str_('T_232'), np.str_('T_231'), np.str_('T_257'), np.str_('T_95'), np.str_('T_104'), np.str_('T_236'), np.str_('T_226'), np.str_('T_164'), np.str_('T_10'), np.str_('T_251'), np.str_('T_109'), np.str_('T_167'), np.str_('T_238'), np.str_('T_49'), np.str_('T_77'), np.str_('T_247'), np.str_('T_216'), np.str_('T_115'), np.str_('T_76'), np.str_('T_9'), np.str_('T_3'), np.str_('T_149'), np.str_('T_235'), np.str_('T_110'), np.str_('T_193'), np.str_('T_29'), np.str_('T_28'), np.str_('T_198'), np.str_('T_98'), np.str_('T_119'), np.str_('T_1'), np.str_('T_203'), np.str_('T_179'), np.str_('T_37'), np.str_('T_174'), np.str_('T_144'), np.str_('T_199'), np.str_('T_75'), np.str_('T_230'), np.str_('T_224'), np.str_('T_111'), np.str_('T_178'), np.str_('T_180'), np.str_('T_33'), np.str_('T_93'), np.str_('T_21'), np.str_('T_222'), np.str_('T_19'), np.str_('T_194'), np.str_('T_35'), np.str_('T_241'), np.str_('T_5'), np.str_('T_100'), np.str_('T_219'), np.str_('T_248'), np.str_('T_206'), np.str_('T_185'), np.str_('T_220')], 'sampled_index': [11, 100, 66, 134, 83, 93, 78, 57, 40, 121, 56, 27, 45, 4, 123, 152, 147, 90, 28, 76, 110, 9, 170, 141, 8, 44, 47, 22, 142, 14, 31, 117, 149, 7, 59, 127, 79, 36, 113, 39, 125, 16, 29, 10, 95, 132, 143, 137, 161, 32, 133, 166, 144, 2, 86, 97, 37, 82, 177, 122, 173, 114, 18, 103, 176, 41, 55, 128, 63, 64, 60, 89, 94, 104, 181, 80, 48, 84, 116, 71, 35, 106, 174, 42, 155, 139, 108, 107, 180, 38, 129, 164, 19, 85, 43, 102, 91, 24, 17, 54, 92, 53, 160, 49, 46, 87, 168, 69, 105, 112, 75, 126, 145, 178, 88, 146, 33, 12, 99, 58, 96, 169, 70, 159, 158, 179, 62, 68, 163, 156, 109, 6, 175, 72, 111, 165, 34, 52, 171, 148, 77, 51, 5, 1, 101, 162, 73, 130, 21, 20, 135, 65, 81, 0, 138, 119, 26, 115, 98, 136, 50, 157, 154, 74, 118, 120, 23, 61, 15, 153, 13, 131, 2 ...
#         [ 0.6088,  1.2696,  0.2245,  ...,  0.2308, -0.5040, -0.2106],
#         [-0.9391, -1.0141, -0.6873,  ..., -0.5995, -0.1015, -0.9503],
#         ...,
#         [ 0.9189,  0.3262,  0.6472,  ...,  0.5965,  0.0647,  1.2814],
#         [ 0.3249,  0.1356,  0.9906,  ...,  1.1296,  0.4212,  1.1494],
#         [ 1.2286,  0.7886,  1.1233,  ...,  1.3897,  1.2952,  1.2102]],
#        device='mps:0'), 'metadata':                    img_paths extra_class_labels early
# T_17    ALY-2_SYS721_t17.tif                 17   '1'
# T_147  ALY-2_SYS721_t147.tif                147   '0'
# T_99    ALY-2_SYS721_t99.tif                 99   '0'
# T_197  ALY-2_SYS721_t197.tif                197   '0'
# T_121  ALY-2_SYS721_t121.tif                121   '0'
# ...                      ...                ...   ...
# T_219  ALY-2_SYS721_t219.tif                219   '0'
# T_248  ALY-2_SYS721_t248.tif                248   '0'
# T_206  ALY-2_SYS721_t206.tif                206   '0'
# T_185  ALY-2_SYS721_t185.tif                185   '0'
# T_220  ALY-2_SYS721_t220.tif                220   '0'
#
# [181 rows x 3 columns], 'sample_ids': [np.str_('T_17'), np.str_('T_147'), np.str_('T_99'), np.str_('T_197'), np.str_('T_121'), np.str_('T_138'), np.str_('T_116'), np.str_('T_85'), np.str_('T_59'), np.str_('T_181'), np.str_('T_84'), np.str_('T_40'), np.str_('T_65'), np.str_('T_6'), np.str_('T_184'), np.str_('T_221'), np.str_('T_215'), np.str_('T_130'), np.str_('T_41'), np.str_('T_114'), np.str_('T_165'), np.str_('T_14'), np.str_('T_244'), np.str_('T_207'), np.str_('T_12'), np.str_('T_64'), np.str_('T_69'), np.str_('T_31'), np.str_('T_208'), np.str_('T_20'), np.str_('T_45'), np.str_('T_177'), np.str_('T_218'), np.str_('T_11'), np.str_('T_88'), np.str_('T_188'), np.str_('T_117'), np.str_('T_54'), np.str_('T_171'), np.str_('T_58'), np.str_('T_186'), np.str_('T_23'), np.str_('T_42'), np.str_('T_15'), np.str_('T_140'), np.str_('T_195'), np.str_('T_210'), np.str_('T_201'), np.str_('T_234'), np.str_('T_46'), np.str_('T_196'), np.str_('T_239'), np.str_('T_212'), np.str_('T_4'), np.str_('T_124'), np.str_('T_143'), np.str_('T_56'), np.str_('T_120'), np.str_('T_255'), np.str_('T_182'), np.str_('T_249'), np.str_('T_172'), np.str_('T_25'), np.str_('T_151'), np.str_('T_252'), np.str_('T_61'), np.str_('T_82'), np.str_('T_189'), np.str_('T_96'), np.str_('T_97'), np.str_('T_90'), np.str_('T_128'), np.str_('T_139'), np.str_('T_152'), np.str_('T_260'), np.str_('T_118'), np.str_('T_72'), np.str_('T_122'), np.str_('T_175'), np.str_('T_107'), np.str_('T_53'), np.str_('T_155'), np.str_('T_250'), np.str_('T_62'), np.str_('T_225'), np.str_('T_205'), np.str_('T_163'), np.str_('T_157'), np.str_('T_259'), np.str_('T_57'), np.str_('T_190'), np.str_('T_237'), np.str_('T_27'), np.str_('T_123'), np.str_('T_63'), np.str_('T_150'), np.str_('T_133'), np.str_('T_34'), np.str_('T_24'), np.str_('T_80'), np.str_('T_134'), np.str_('T_79'), np.str_('T_233'), np.str_('T_74'), np.str_('T_68'), np.str_('T_126'), np.str_('T_242'), np.str_('T_105'), np.str_('T_153'), np.str_('T_168'), np.str_('T_112'), np.str_('T_187'), np.str_('T_213'), np.str_('T_256'), np.str_('T_127'), np.str_('T_214'), np.str_('T_47'), np.str_('T_18'), np.str_('T_145'), np.str_('T_86'), np.str_('T_141'), np.str_('T_243'), np.str_('T_106'), np.str_('T_232'), np.str_('T_231'), np.str_('T_257'), np.str_('T_95'), np.str_('T_104'), np.str_('T_236'), np.str_('T_226'), np.str_('T_164'), np.str_('T_10'), np.str_('T_251'), np.str_('T_109'), np.str_('T_167'), np.str_('T_238'), np.str_('T_49'), np.str_('T_77'), np.str_('T_247'), np.str_('T_216'), np.str_('T_115'), np.str_('T_76'), np.str_('T_9'), np.str_('T_3'), np.str_('T_149'), np.str_('T_235'), np.str_('T_110'), np.str_('T_193'), np.str_('T_29'), np.str_('T_28'), np.str_('T_198'), np.str_('T_98'), np.str_('T_119'), np.str_('T_1'), np.str_('T_203'), np.str_('T_179'), np.str_('T_37'), np.str_('T_174'), np.str_('T_144'), np.str_('T_199'), np.str_('T_75'), np.str_('T_230'), np.str_('T_224'), np.str_('T_111'), np.str_('T_178'), np.str_('T_180'), np.str_('T_33'), np.str_('T_93'), np.str_('T_21'), np.str_('T_222'), np.str_('T_19'), np.str_('T_194'), np.str_('T_35'), np.str_('T_241'), np.str_('T_5'), np.str_('T_100'), np.str_('T_219'), np.str_('T_248'), np.str_('T_206'), np.str_('T_185'), np.str_('T_220')], 'sampled_index': [11, 100, 66, 134, 83, 93, 78, 57, 40, 121, 56, 27, 45, 4, 123, 152, 147, 90, 28, 76, 110, 9, 170, 141, 8, 44, 47, 22, 142, 14, 31, 117, 149, 7, 59, 127, 79, 36, 113, 39, 125, 16, 29, 10, 95, 132, 143, 137, 161, 32, 133, 166, 144, 2, 86, 97, 37, 82, 177, 122, 173, 114, 18, 103, 176, 41, 55, 128, 63, 64, 60, 89, 94, 104, 181, 80, 48, 84, 116, 71, 35, 106, 174, 42, 155, 139, 108, 107, 180, 38, 129, 164, 19, 85, 43, 102, 91, 24, 17, 54, 92, 53, 160, 49, 46, 87, 168, 69, 105, 112, 75, 126, 145, 178, 88, 146, 33, 12, 99, 58, 96, 169, 70, 159, 158, 179, 62, 68, 163, 156, 109, 6, 175, 72, 111, 165, 34, 52, 171, 148, 77, 51, 5, 1, 101, 162, 73, 130, 21, 20, 135, 65, 81, 0, 138, 119, 26, 115, 98, 136, 50, 157, 154, 74, 118, 120, 23, 61, 15, 153, 13, 131, 2 ...
#             1.4286e-01,  1.4286e-01],
#           [ 1.4286e-01,  1.4286e-01,  1.1429e-01,  ...,  8.5714e-02,
#             8.5714e-02,  8.5714e-02],
#           [ 1.1429e-01,  1.4286e-01,  1.1429e-01,  ...,  1.1429e-01,
#             8.5714e-02,  8.5714e-02],
#           ...,
#           [ 8.5714e-02,  8.5714e-02,  8.5714e-02,  ...,  5.7143e-02,
#           [ 5.3333e-02,  6.6667e-02,  5.3333e-02,  ...,  5.3333e-02,
#             4.0000e-02,  5.3333e-02],
#           ...,
#           [ 4.0000e-02,  1.3333e-02,  4.0000e-02,  ...,  2.6667e-02,
#             2.6667e-02, -1.8626e-09],
#           [ 2.6667e-02,  1.3333e-02,  1.3333e-02,  ...,  1.3333e-02,
#             2.6667e-02,  1.3333e-02],
#           [ 2.6667e-02,  2.6667e-02,  2.6667e-02,  ...,  1.3333e-02,
#             1.3333e-02,  1.3333e-02]]],
#
#
#         [[[ 6.5789e-02,  6.5789e-02,  6.5789e-02,  ...,  6.5789e-02,
#             6.5789e-02,  5.2632e-02],
#           [ 7.8947e-02,  7.8947e-02,  6.5789e-02,  ...,  5.2632e-02,
#             5.2632e-02,  5.2632e-02],
#           [ 6.5789e-02,  7.8947e-02,  6.5789e-02,  ...,  6.5789e-02,
#             6.5789e-02,  5.2632e-02],
#           ...,
#           [ 3.9474e-02,  3.9474e-02,  3.9474e-02,  ...,  1.3158e-02,
#             2.6316e-02,  3.7253e-09],
#           [ 1.3158e-02,  2.6316e-02,  3.9474e-02,  ...,  2.6316e-02,
#             2.6316e-02,  2.6316e-02],
#           [ 1.3158e-02,  3.9474e-02,  3.9474e-02,  ...,  2.6316e-02,
#             2.6316e-02,  1.3158e-02]]]], device='mps:0'), 'metadata':                    img_paths extra_class_labels early
# T_17    ALY-2_SYS721_t17.tif                 17   '1'
# T_147  ALY-2_SYS721_t147.tif                147   '0'
# T_99    ALY-2_SYS721_t99.tif                 99   '0'
# T_197  ALY-2_SYS721_t197.tif                197   '0'
# T_121  ALY-2_SYS721_t121.tif                121   '0'
# ...                      ...                ...   ...
# T_219  ALY-2_SYS721_t219.tif                219   '0'
# T_248  ALY-2_SYS721_t248.tif                248   '0'
# T_206  ALY-2_SYS721_t206.tif                206   '0'
# T_185  ALY-2_SYS721_t185.tif                185   '0'
# T_220  ALY-2_SYS721_t220.tif                220   '0'
#
# [181 rows x 3 columns], 'sample_ids': [np.str_('T_17'), np.str_('T_147'), np.str_('T_99'), np.str_('T_197'), np.str_('T_121'), np.str_('T_138'), np.str_('T_116'), np.str_('T_85'), np.str_('T_59'), np.str_('T_181'), np.str_('T_84'), np.str_('T_40'), np.str_('T_65'), np.str_('T_6'), np.str_('T_184'), np.str_('T_221'), np.str_('T_215'), np.str_('T_130'), np.str_('T_41'), np.str_('T_114'), np.str_('T_165'), np.str_('T_14'), np.str_('T_244'), np.str_('T_207'), np.str_('T_12'), np.str_('T_64'), np.str_('T_69'), np.str_('T_31'), np.str_('T_208'), np.str_('T_20'), np.str_('T_45'), np.str_('T_177'), np.str_('T_218'), np.str_('T_11'), np.str_('T_88'), np.str_('T_188'), np.str_('T_117'), np.str_('T_54'), np.str_('T_171'), np.str_('T_58'), np.str_('T_186'), np.str_('T_23'), np.str_('T_42'), np.str_('T_15'), np.str_('T_140'), np.str_('T_195'), np.str_('T_210'), np.str_('T_201'), np.str_('T_234'), np.str_('T_46'), np.str_('T_196'), np.str_('T_239'), np.str_('T_212'), np.str_('T_4'), np.str_('T_124'), np.str_('T_143'), np.str_('T_56'), np.str_('T_120'), np.str_('T_255'), np.str_('T_182'), np.str_('T_249'), np.str_('T_172'), np.str_('T_25'), np.str_('T_151'), np.str_('T_252'), np.str_('T_61'), np.str_('T_82'), np.str_('T_189'), np.str_('T_96'), np.str_('T_97'), np.str_('T_90'), np.str_('T_128'), np.str_('T_139'), np.str_('T_152'), np.str_('T_260'), np.str_('T_118'), np.str_('T_72'), np.str_('T_122'), np.str_('T_175'), np.str_('T_107'), np.str_('T_53'), np.str_('T_155'), np.str_('T_250'), np.str_('T_62'), np.str_('T_225'), np.str_('T_205'), np.str_('T_163'), np.str_('T_157'), np.str_('T_259'), np.str_('T_57'), np.str_('T_190'), np.str_('T_237'), np.str_('T_27'), np.str_('T_123'), np.str_('T_63'), np.str_('T_150'), np.str_('T_133'), np.str_('T_34'), np.str_('T_24'), np.str_('T_80'), np.str_('T_134'), np.str_('T_79'), np.str_('T_233'), np.str_('T_74'), np.str_('T_68'), np.str_('T_126'), np.str_('T_242'), np.str_('T_105'), np.str_('T_153'), np.str_('T_168'), np.str_('T_112'), np.str_('T_187'), np.str_('T_213'), np.str_('T_256'), np.str_('T_127'), np.str_('T_214'), np.str_('T_47'), np.str_('T_18'), np.str_('T_145'), np.str_('T_86'), np.str_('T_141'), np.str_('T_243'), np.str_('T_106'), np.str_('T_232'), np.str_('T_231'), np.str_('T_257'), np.str_('T_95'), np.str_('T_104'), np.str_('T_236'), np.str_('T_226'), np.str_('T_164'), np.str_('T_10'), np.str_('T_251'), np.str_('T_109'), np.str_('T_167'), np.str_('T_238'), np.str_('T_49'), np.str_('T_77'), np.str_('T_247'), np.str_('T_216'), np.str_('T_115'), np.str_('T_76'), np.str_('T_9'), np.str_('T_3'), np.str_('T_149'), np.str_('T_235'), np.str_('T_110'), np.str_('T_193'), np.str_('T_29'), np.str_('T_28'), np.str_('T_198'), np.str_('T_98'), np.str_('T_119'), np.str_('T_1'), np.str_('T_203'), np.str_('T_179'), np.str_('T_37'), np.str_('T_174'), np.str_('T_144'), np.str_('T_199'), np.str_('T_75'), np.str_('T_230'), np.str_('T_224'), np.str_('T_111'), np.str_('T_178'), np.str_('T_180'), np.str_('T_33'), np.str_('T_93'), np.str_('T_21'), np.str_('T_222'), np.str_('T_19'), np.str_('T_194'), np.str_('T_35'), np.str_('T_241'), np.str_('T_5'), np.str_('T_100'), np.str_('T_219'), np.str_('T_248'), np.str_('T_206'), np.str_('T_185'), np.str_('T_220')], 'sampled_index': [180, 137, 109, 110, 150, 31, 14, 45, 96, 88, 49, 71, 97, 84, 140, 93, 39, 176, 82, 0, 56, 172, 170, 61, 157, 85, 83, 8, 91, 17, 33, 32, 146, 163, 126, 37, 7, 69, 57, 86, 125, 27, 66, 167, 114, 87, 75, 38, 90, 43, 104, 77, 63, 113, 177, 98, 65, 156, 162, 103, 10, 70, 6, 127, 178, 138, 78, 41, 79, 73, 48, 2, 24, 149, 12, 175, 112, 159, 52, 22, 51, 102, 171, 116, 142, 76, 34, 99, 20, 58, 139, 106, 3, 164, 130, 118, 168, 18, 15, 59, 158, 35, 124, 148, 68, 173, 155, 28, 136, 111, 19, 120, 60, 154, 166, 40, 53, 13, 131, 36, 100, 152, 16, 122, 143, 153, 64, 29, 108, 123, 67, 160, 169, 151, 81, 74, 133, 129, 179, 46, 5, 119, 54, 135, 50, 92, 30, 121, 165, 174, 80, 105, 181, 128, 47, 132, 26, 44, 117, 72, 134, 144, 145, 25, 115, 94, 4, 42, 23, 107, 9, 95, ...

# %%
f = next(iter(batch))
f
# Out:
# 'multi_bulk.RNA'

# %%
xmodalix.save("xmodalix.pkl")
# Out:
# Pipeline object saved successfully.
# Preprocessor saved successfully.
# Model state saved successfully.

# %%
xmodalix = acx.XModalix.load("xmodalix.pkl")
# Out:
# Attempting to load a pipeline from xmodalix.pkl...
# Pipeline object loaded successfully. Actual type: XModalix
# Preprocessor loaded successfully.
# Model state loaded successfully.

# %% [markdown]
# ### Inspect X-Modalix Result

# %%
r = xmodalix.result

# %% [markdown]
# Trainingdynamics in result are a dict with keys for each datamodality, the get interface works like for the other pipelines.
# We have the special keys:
# - translation which is the actual translated reconstruction or the from_latent space for the latentspace dynamic

# %%
r.reconstructions.get(epoch=-1, split="test").keys()
# Out:
# dict_keys(['multi_bulk.RNA', 'multi_bulk.RNA2', 'img.IMG', 'translation', 'reference_img.IMG_to_img.IMG'])

# %% [markdown]
# We have latentspaces for the test set for each modality, not only for the translation pairing

# %%
r.latentspaces.get(epoch=-1, split="test")
# Out:
# {'multi_bulk.RNA': array([[-1.03933883e+00,  7.35084534e-01,  1.73693895e+00,
#           6.23674095e-01,  1.09553218e+00,  1.62421286e+00,
#           1.80105257e+00,  4.10075635e-01],
#         [ 1.43173373e+00,  8.47205400e-01,  6.40210450e-01,
#          -2.10476065e+00,  1.87384033e+00,  2.73016572e+00,
#          -6.05041921e-01,  4.21301782e-01],
#         [ 4.29294944e-01,  1.08289659e+00, -8.23563635e-01,
#          -1.55920357e-01,  5.78647375e-01, -1.59058571e-02,
#           1.35561812e+00, -2.79702544e-01],
#         [ 3.62493038e-01, -2.93677592e+00, -5.03645718e-01,
#           5.55252194e-01,  1.43954158e+00, -9.94637191e-01,
#           9.79726240e-02,  6.57447934e-01],
#         [ 6.56282127e-01,  6.18035555e-01,  2.57447910e+00,
#           7.02724159e-01,  9.95994359e-02,  1.45423543e+00,
#          -4.58151013e-01,  1.07350063e+00],
#         [-9.20093298e-01,  2.78475070e+00,  1.03912318e+00,
#           2.67735630e-01, -3.08382601e-01, -2.49669999e-02,
#          -1.56342351e+00, -1.24071813e+00],
#         [-1.02352500e+00,  2.51487088e+00,  5.64278960e-01,
#           1.40707493e+00,  1.86993778e-01,  1.73452652e+00,
#           1.21190941e+00, -8.34475279e-01],
#         [ 2.00664401e+00, -2.85940081e-01,  1.65011272e-01,
#           6.43924415e-01, -5.84938824e-01,  8.53226781e-01,
#          -1.12490535e+00,  1.14176273e-01],
#         [ 1.53847635e+00,  1.54025483e+00, -4.54418719e-01,
#           3.41093391e-01,  1.29823744e+00, -6.00524008e-01,
#           7.20224082e-01, -5.79209924e-01],
#         [ 1.27087641e+00,  4.46293950e-02,  6.08826816e-01,
#           1.79819226e+00,  1.81880760e+00,  7.94923246e-01,
#           3.46049070e-01,  1.42800033e-01],
#         [ 3.75187397e-01,  1.02376223e-01,  1.29486787e+00,
#           1.86150396e+00,  1.03066838e+00, -4.25416678e-01,
#          -4.99450594e-01,  1.80214357e+00],
#         [ 1.25207973e+00,  1.64995241e+00,  3.13640165e+00,
#           1.39635623e+00, -3.31932515e-01, -1.32732499e+00,
#           8.42282623e-02, -1.65055871e-01],
#         [ 1.73398113e+00,  1.87807918e+00, -6.34227216e-01,
#          -2.14474201e-01,  7.75897324e-01,  2.44488978e+00,
#          -5.25384724e-01,  4.29363936e-01],
#         [ 9.49106514e-01, -2.85829067e-01, -1.08262524e-01,
#           1.40740645e+00,  9.81774390e-01, -3.63704488e-02,
#           3.60775068e-02,  2.21216822e+00],
#         [ 2.16235089e+00,  1.59772456e-01,  8.19834881e-03,
#           3.40090322e+00,  5.02216756e-01,  5.73404372e-01,
#          -2.28309464e+00,  7.72019625e-01],
#         [ 3.07532668e-01, -2.50828862e-01, -9.09075961e-02,
#           4.99805927e-01, -8.52177739e-01, -3.73486102e-01,
#          -9.96939778e-01, -6.50725901e-01],
#         [ 1.32301593e+00,  8.15211892e-01, -5.81323683e-01,
#           8.84793460e-01,  6.65620863e-01,  1.32002532e+00,
#          -8.06841552e-01, -1.69355869e-01],
#         [-7.08329678e-02,  2.18113017e+00,  3.85006815e-02,
#           2.92110252e+00, -1.91544557e+00, -2.51416492e+00,
#          -3.32765430e-01,  6.20567799e-01],
#         [ 1.81914747e+00, -5.39358377e-01,  1.65034807e+00,
#           1.05081570e+00, -1.58920801e+00,  1.30841419e-01,
#           3.93374145e-01,  2.41630173e+00]], dtype=float32)}

# %% [markdown]
# We also provide the andata interface for the translate latentspace (from_modality)

# %%
r.adata_latent.obs_names
# Out:
# Index(['T_108', 'T_113', 'T_125', 'T_129', 'T_13', 'T_135', 'T_136', 'T_137',
#        'T_142', 'T_154', 'T_156', 'T_16', 'T_161', 'T_162', 'T_169', 'T_170',
#        'T_173', 'T_176', 'T_200', 'T_202', 'T_204', 'T_211', 'T_217', 'T_22',
#        'T_223', 'T_227', 'T_228', 'T_229', 'T_253', 'T_254', 'T_258', 'T_26',
#        'T_32', 'T_36', 'T_38', 'T_39', 'T_44', 'T_48', 'T_51', 'T_52', 'T_55',
#        'T_66', 'T_67', 'T_7', 'T_70', 'T_71', 'T_78', 'T_81', 'T_83', 'T_89',
#        'T_91', 'T_94'],
#       dtype='object')

# %% [markdown]
# And we also support the final_reconstruction attribute that returns the same datastructure as the input data, but switches the actual data with the translated reconstruction (for the translted modality, the rest is the same as the input data)

# %%
final_rec = r.final_reconstruction.datasets["img.IMG"]
inputimg = xmodalix.result.datasets.test.datasets["img.IMG"]

# %% [markdown]
# ## Vis 2D aligned latent development

# %%
## from old autoecodix framework
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

def plot_translate_latent(
    # cfg, -> removed
    embedding,
    color_param,
    style_param=None,
    save_fig="",
):
    """
    Creates a 2D visualization of the 2D embedding of the latent space.
    ARGS:
        cfg (dict): config dictionary
        embedding (pd.DataFrame): embedding on which is visualized. Assumes prior 2D dimension reduction.
        color_param (str): Clinical parameter to color scatter plot
        style_param (str): Parameter e.g. "Translate" to facet scatter plot
        save_fig (str): File path for saving the plot. Use appropriate file
                        endings to specify image type (e.g. '*.png')
    RETURNS:
        fig (seaborn.FacetGrid): Figure handle

    """
    labels = embedding[color_param]
    # logger = getlogger(cfg)
    numeric = False
    if not (type(labels[0]) is str):
        if len(np.unique(labels)) > 3:
            # if not cfg["PLOT_NUMERIC"]:
            # print(
            #     f"The provided label column is numeric and converted to categories."
            # )
            # labels = pd.qcut(
            #     labels, q=4, labels=["1stQ", "2ndQ", "3rdQ", "4thQ"]
            # ).astype(str)
            # else:
            numeric = True
        else:
            labels = [str(x) for x in labels]

    # check if label or embedding is longerm and duplicate the shorter one
    if len(labels) < embedding.shape[0]:
        print(
            "Given labels do not have the same length as given sample size. Labels will be duplicated."
        )
        labels = [
            label for label in labels for _ in range(embedding.shape[0] // len(labels))
        ]
    elif len(labels) > embedding.shape[0]:
        labels = list(set(labels))

    if not style_param == None:
        embedding[color_param] = labels
        if numeric:
            palette = "bwr"
        else:
            palette = None
        plot = sns.relplot(
            data=embedding,
            x="DIM1",
            y="DIM2",
            hue=color_param,
            palette=palette,
            col=style_param,
            style=style_param,
            markers=True,
            alpha=0.4,
            ec="black",
            height=10,
            aspect=1,
            s=150,
        )

    if len(save_fig) > 0:
        plot.savefig(save_fig, bbox_inches="tight")

    return plot

# %%
## Collect all metadata and latent spaces from datasets
clin_data = []
latent_data = []

for split in ["train", "test", "valid"]:
	split_ds = getattr(r.datasets, split, None)
	if split_ds is not None:
		for key, ds in split_ds.datasets.items():
			df_latent = r.get_latent_df(epoch=-1, split=split, modality=key)
			df_latent["modality"] = key
			df_latent["sample_ids"] = df_latent.index # Each sample can occur multiple times in latent space
			latent_data.append(df_latent)
			if hasattr(ds, "metadata") and ds.metadata is not None:
				df = ds.metadata.copy()
				# Add sample_ids as a column if it's the index
				if df.index.name == "sample_ids" and "sample_ids" not in df.columns:
					print(key)
					print(df)
					df = df.reset_index()
				df["split"] = split
				df["modality"] = key
				clin_data.append(df)

if latent_data and clin_data:
	latent_data = pd.concat(latent_data, axis=0, ignore_index=True)
	clin_data = pd.concat(clin_data, axis=0, ignore_index=True)
	if "sample_ids" in clin_data.columns:
		clin_data = clin_data.drop_duplicates(subset="sample_ids").set_index("sample_ids")
else:
	latent_data = pd.DataFrame()
	clin_data = pd.DataFrame()
# Out:
# img.IMG
#                         img_paths  extra_class_labels early
# sample_ids
# T_114       ALY-2_SYS721_t114.tif                 114   '0'
# T_100       ALY-2_SYS721_t100.tif                 100   '0'
# T_128       ALY-2_SYS721_t128.tif                 128   '0'
# T_27         ALY-2_SYS721_t27.tif                  27   '1'
# T_33         ALY-2_SYS721_t33.tif                  33   '1'
# ...                           ...                 ...   ...
# T_124       ALY-2_SYS721_t124.tif                 124   '0'
# T_252       ALY-2_SYS721_t252.tif                 252   '0'
# T_247       ALY-2_SYS721_t247.tif                 247   '0'
# T_17         ALY-2_SYS721_t17.tif                  17   '1'
# T_119       ALY-2_SYS721_t119.tif                 119   '0'
#
# [182 rows x 3 columns]
# img.IMG
#                         img_paths  extra_class_labels early
# sample_ids
# T_32         ALY-2_SYS721_t32.tif                  32   '1'
# T_26         ALY-2_SYS721_t26.tif                  26   '1'
# T_129       ALY-2_SYS721_t129.tif                 129   '0'
# T_258       ALY-2_SYS721_t258.tif                 258   '0'
# T_113       ALY-2_SYS721_t113.tif                 113   '0'
# T_22         ALY-2_SYS721_t22.tif                  22   '1'
# T_36         ALY-2_SYS721_t36.tif                  36   '1'
# T_51         ALY-2_SYS721_t51.tif                  51   '0'
# T_229       ALY-2_SYS721_t229.tif                 229   '0'
# T_228       ALY-2_SYS721_t228.tif                 228   '0'
# T_200       ALY-2_SYS721_t200.tif                 200   '0'
# T_78         ALY-2_SYS721_t78.tif                  78   '0'
# T_44         ALY-2_SYS721_t44.tif                  44   '0'
# T_162       ALY-2_SYS721_t162.tif                 162   '0'
# T_176       ALY-2_SYS721_t176.tif                 176   '0'
# T_52         ALY-2_SYS721_t52.tif                  52   '0'
# T_91         ALY-2_SYS721_t91.tif                  91   '0'
# T_202       ALY-2_SYS721_t202.tif                 202   '0'
# T_217       ALY-2_SYS721_t217.tif                 217   '0'
# T_161       ALY-2_SYS721_t161.tif                 161   '0'
# T_94         ALY-2_SYS721_t94.tif                  94   '0'
# T_81         ALY-2_SYS721_t81.tif                  81   '0'
# T_170       ALY-2_SYS721_t170.tif                 170   '0'
# T_83         ALY-2_SYS721_t83.tif                  83   '0'
# T_204       ALY-2_SYS721_t204.tif                 204   '0'
# T_211       ALY-2_SYS721_t211.tif                 211   '0'
# T_55         ALY-2_SYS721_t55.tif                  55   '0'
# T_173       ALY-2_SYS721_t173.tif                 173   '0'
# T_156       ALY-2_SYS721_t156.tif                 156   '0'
# T_70         ALY-2_SYS721_t70.tif                  70   '0'
# T_142       ALY-2_SYS721_t142.tif                 142   '0'
# T_7           ALY-2_SYS721_t7.tif                   7   '1'
# T_71         ALY-2_SYS721_t71.tif                  71   '0'
# T_67         ALY-2_SYS721_t67.tif                  67   '0'
# T_169       ALY-2_SYS721_t169.tif                 169   '0'
# T_223       ALY-2_SYS721_t223.tif                 223   '0'
# T_154       ALY-2_SYS721_t154.tif                 154   '0'
# T_66         ALY-2_SYS721_t66.tif                  66   '0'
# T_89         ALY-2_SYS721_t89.tif                  89   '0'
# T_227       ALY-2_SYS721_t227.tif                 227   '0'
# T_48         ALY-2_SYS721_t48.tif                  48   '0'
# T_13         ALY-2_SYS721_t13.tif                  13   '1'
# T_135       ALY-2_SYS721_t135.tif                 135   '0'
# T_108       ALY-2_SYS721_t108.tif                 108   '0'
# T_136       ALY-2_SYS721_t136.tif                 136   '0'
# T_38         ALY-2_SYS721_t38.tif                  38   '1'
# T_254       ALY-2_SYS721_t254.tif                 254   '0'
# T_39         ALY-2_SYS721_t39.tif                  39   '1'
# T_137       ALY-2_SYS721_t137.tif                 137   '0'
# T_16         ALY-2_SYS721_t16.tif                  16   '1'
# T_253       ALY-2_SYS721_t253.tif                 253   '0'
# T_125       ALY-2_SYS721_t125.tif                 125   '0'
# img.IMG
#                         img_paths  extra_class_labels early
# sample_ids
# T_101       ALY-2_SYS721_t101.tif                 101   '0'
# T_103       ALY-2_SYS721_t103.tif                 103   '0'
# T_30         ALY-2_SYS721_t30.tif                  30   '1'
# T_102       ALY-2_SYS721_t102.tif                 102   '0'
# T_92         ALY-2_SYS721_t92.tif                  92   '0'
# T_87         ALY-2_SYS721_t87.tif                  87   '0'
# T_50         ALY-2_SYS721_t50.tif                  50   '0'
# T_160       ALY-2_SYS721_t160.tif                 160   '0'
# T_148       ALY-2_SYS721_t148.tif                 148   '0'
# T_159       ALY-2_SYS721_t159.tif                 159   '0'
# T_8           ALY-2_SYS721_t8.tif                   8   '1'
# T_158       ALY-2_SYS721_t158.tif                 158   '0'
# T_166       ALY-2_SYS721_t166.tif                 166   '0'
# T_209       ALY-2_SYS721_t209.tif                 209   '0'
# T_73         ALY-2_SYS721_t73.tif                  73   '0'
# T_183       ALY-2_SYS721_t183.tif                 183   '0'
# T_192       ALY-2_SYS721_t192.tif                 192   '0'
# T_191       ALY-2_SYS721_t191.tif                 191   '0'
# T_146       ALY-2_SYS721_t146.tif                 146   '0'
# T_60         ALY-2_SYS721_t60.tif                  60   '0'
# T_2           ALY-2_SYS721_t2.tif                   2   '1'
# T_240       ALY-2_SYS721_t240.tif                 240   '0'
# T_245       ALY-2_SYS721_t245.tif                 245   '0'
# T_132       ALY-2_SYS721_t132.tif                 132   '0'
# T_246       ALY-2_SYS721_t246.tif                 246   '0'
# T_131       ALY-2_SYS721_t131.tif                 131   '0'

# %%
from umap import UMAP

## Make 2D Embedding with UMAP
if latent_data.drop(columns=["sample_ids", "modality"]).shape[1] > 2:
	reducer = UMAP(n_components=2)
	embedding = pd.DataFrame(reducer.fit_transform(latent_data.drop(columns=["sample_ids", "modality"])))
	embedding.columns = ["DIM1", "DIM2"]
	embedding["sample_ids"] = latent_data["sample_ids"]
	embedding["modality"] = latent_data["modality"]
else:
	embedding = latent_data

# Merge with clinical data via sample_ids
embedding = embedding.merge(clin_data.drop(columns=["modality"]), on="sample_ids", how="left")

embedding
# Out:
# /Users/maximilianjoas/development/autoencodix_package/.venv/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
#           DIM1      DIM2 sample_ids        modality              img_paths  \
# 0    11.482251  3.911896        T_1  multi_bulk.RNA    ALY-2_SYS721_t1.tif
# 1    12.767270  2.233753       T_10  multi_bulk.RNA   ALY-2_SYS721_t10.tif
# 2    12.541024  2.878924      T_100  multi_bulk.RNA  ALY-2_SYS721_t100.tif
# 3    12.171851  4.459630      T_104  multi_bulk.RNA  ALY-2_SYS721_t104.tif
# 4    12.630878  2.817362      T_105  multi_bulk.RNA  ALY-2_SYS721_t105.tif
# ..         ...       ...        ...             ...                    ...
# 775  10.723070  4.527559       T_60         img.IMG   ALY-2_SYS721_t60.tif
# 776  10.809166  4.308156       T_73         img.IMG   ALY-2_SYS721_t73.tif
# 777  10.780701  3.774436        T_8         img.IMG    ALY-2_SYS721_t8.tif
# 778   9.151770  4.442171       T_87         img.IMG   ALY-2_SYS721_t87.tif
# 779   9.413368  5.623876       T_92         img.IMG   ALY-2_SYS721_t92.tif
#
#      extra_class_labels early  split
# 0                     1   '1'  train
# 1                    10   '1'  train
# 2                   100   '0'  train
# 3                   104   '0'  train
# 4                   105   '0'  train
# ..                  ...   ...    ...
# 775                  60   '0'  valid
# 776                  73   '0'  valid
# 777                   8   '1'  valid
# 778                  87   '0'  valid
# 779                  92   '0'  valid
#
# [780 rows x 8 columns]

# %%
param = "extra_class_labels"
sns.set_theme(font_scale=2)
sns.set_style("white")

plot = plot_translate_latent(
	embedding=embedding,
	color_param=param,
	style_param="modality",
)

# %%
latent_data
# Out:
#      LatDim_0  LatDim_1  LatDim_2  LatDim_3  LatDim_4  LatDim_5  LatDim_6  \
# 0    2.301566  0.242048 -0.211997 -0.535960  0.788841 -1.736060  0.386838
# 1   -0.368044  0.417774  1.326512  0.686062  2.152880  0.736907 -0.568590
# 2   -1.050296 -2.448417  1.595794  0.802328  1.543893  2.070535  0.874692
# 3    2.428741 -0.387180 -0.394850 -0.718770 -1.467882  0.245126  0.729714
# 4   -0.097271 -0.333466  2.564382 -0.883170  3.168455  1.274577  2.945304
# ..        ...       ...       ...       ...       ...       ...       ...
# 775  1.222490  0.423636 -0.741822  0.180276 -0.448090 -1.211199 -1.129706
# 776  2.322850 -0.193156  0.584067  0.286964  0.554497 -1.498007 -0.153336
# 777  1.184098  0.276504 -0.663418  1.941789 -0.335197  0.851010 -0.278441
# 778 -0.994493  1.603772  0.677728  0.977726 -0.364432  0.553639 -0.542335
# 779  2.269523  0.472992  0.086610  1.626356  1.062372  0.043554  0.663338
#
#      LatDim_7        modality sample_ids
# 0   -2.529181  multi_bulk.RNA        T_1
# 1    0.349346  multi_bulk.RNA       T_10
# 2   -2.488033  multi_bulk.RNA      T_100
# 3    0.562612  multi_bulk.RNA      T_104
# 4   -4.635080  multi_bulk.RNA      T_105
# ..        ...             ...        ...
# 775  0.785888         img.IMG       T_60
# 776 -0.499902         img.IMG       T_73
# 777  0.312948         img.IMG        T_8
# 778  1.749615         img.IMG       T_87
# 779  2.320347         img.IMG       T_92
#
# [780 rows x 10 columns]

# %% [markdown]
# ### Flexible Prediction
# We train the Xmodalix with multiple data modalities, out of all these modalities, we can build any pair for translation byt passing the keys (as defined in your config or datapackage) to the predict method like:

# %%
result2 = xmodalix.predict(from_key="IMG", to_key="IMG")
# Out:
# Prediction complete.
# Processing latent space results into a single AnnData object...
# Identified source modality for latent space: 'multi_bulk.RNA'
#   - Added 279 source feature IDs to .uns
# Finished processing latent results.

# %% [markdown]
# ### Inspecting losses
# We save all losses in our result object, see the keys here:

# %%
result.sub_losses.keys()
# Out:
# dict_keys(['total_loss', 'adver_loss', 'aggregated_sub_losses', 'paired_loss', 'class_loss', 'multi_bulk.RNA.recon_loss', 'multi_bulk.RNA.var_loss', 'multi_bulk.RNA.anneal_factor', 'multi_bulk.RNA.effective_beta_factor', 'multi_bulk.RNA.loss', 'multi_bulk.RNA2.recon_loss', 'multi_bulk.RNA2.var_loss', 'multi_bulk.RNA2.anneal_factor', 'multi_bulk.RNA2.effective_beta_factor', 'multi_bulk.RNA2.loss', 'img.IMG.recon_loss', 'img.IMG.var_loss', 'img.IMG.anneal_factor', 'img.IMG.effective_beta_factor', 'img.IMG.loss', 'clf_loss'])

# %% [markdown]
# After selecting a subloss, this works like a standard TrainingDynamic

# %%
result.sub_losses.get("adver_loss")
# Out:
# TrainingDynamics()

# %% [markdown]
# ### Visualizing a sample output
# Note this is shown with only one epoch training, I've seen good results for 20 epochs of pretraining img and 30 epochs of normal training

# %%
img = result.reconstructions.get(split="test", epoch=-1)

# %%
img = img["translation"]

# %%
img.shape
# Out:
# (52, 1, 64, 64)

# %%
sample_img = img[0, :, :, :].squeeze()
sample_img.shape
# Out:
# (64, 64)

# %%
sample_img.max()
# Out:
# np.float32(0.56739354)

# %%
import matplotlib.pyplot as plt
plt.imshow(sample_img)

# %% [markdown]
# ### Getting Info about pretraining
# The pretraining is saved in sub_results in the result object

# %%
sub_res = result.sub_results
sub_res
# Out:
# {'multi_bulk.RNA': None,
#  'multi_bulk.RNA2': None,
#  'img.IMG': None,
#  'pretrain.img.IMG': Result Object Public Attributes:
#  ------------------------------
#  latentspaces: TrainingDynamics object
#  sample_ids: TrainingDynamics object
#  reconstructions: TrainingDynamics object
#  mus: TrainingDynamics object
#  sigmas: TrainingDynamics object
#  losses: TrainingDynamics object
#  sub_losses: LossRegistry(_losses={'recon_loss': TrainingDynamics(), 'var_loss': TrainingDynamics(), 'anneal_factor': TrainingDynamics(), 'effective_beta_factor': TrainingDynamics()})
#  preprocessed_data: Tensor of shape (0,)
#  model: ImageVAEArchitecture
#  model_checkpoints: TrainingDynamics object
#  datasets: DatasetContainer(train=None, valid=None, test=None)
#  new_datasets: DatasetContainer(train=None, valid=None, test=None)
#  adata_latent: AnnData object with n_obs × n_vars = 0 × 0
#  final_reconstruction: None
#  sub_results: None
#  sub_reconstructions: None
#  embedding_evaluation: Empty DataFrame
#  Columns: []
#  Index: []}

# %% [markdown]
# ## Xmodal_loss Visualization
# Vibe coded provisory loss visualization

# %%
result.sub_losses.keys()
result.sub_losses.get("img.IMG.var_loss").get()
# Out:
# {0: {'train': array(7.81462081e-06), 'valid': array(3.80482933e-07)},
#  1: {'train': array(0.00042569), 'valid': array(3.42521702e-05)},
#  2: {'train': array(0.0205212), 'valid': array(0.0033392)},
#  3: {'train': array(0.1516158), 'valid': array(0.03871971)},
#  4: {'train': array(0.1717274), 'valid': array(0.06761601)}}

# %%
import matplotlib.pyplot as plt


def plot_losses(result):
    """
    Generates and displays plots for all relevant losses from a Result object.

    Args:
        result: Your custom result object containing the sub_losses attribute.
    """
    if not hasattr(result, "sub_losses"):
        print(
            "Error: The provided result object does not have a 'sub_losses' attribute."
        )
        return

    # 1. Get all loss keys and filter out the factors
    all_loss_keys = result.sub_losses.keys()
    keys_to_plot = [key for key in all_loss_keys if not key.endswith("_factor")]

    if not keys_to_plot:
        print("No valid loss keys found to plot.")
        return

    # 2. Iterate through each loss and create a plot
    for loss_name in keys_to_plot:
        try:
            # Retrieve the nested dictionary for the current loss
            loss_data = result.sub_losses.get(loss_name).get()

            # 3. Unpack the data into lists for plotting
            epochs = sorted(loss_data.keys())
            train_losses = [loss_data[epoch]["train"] for epoch in epochs]

            # Check if validation data exists before trying to plot it
            has_valid_data = all("valid" in loss_data[epoch] for epoch in epochs)
            if has_valid_data:
                valid_losses = [loss_data[epoch]["valid"] for epoch in epochs]

            # 4. Create the plot
            plt.figure(figsize=(10, 6))
            plt.plot(epochs, train_losses, "o-", label=f"Train ({loss_name})")
            if has_valid_data:
                plt.plot(epochs, valid_losses, "x-", label=f"Validation ({loss_name})")

            plt.title(f"Training and Validation Loss: {loss_name}")
            plt.xlabel("Epoch")
            plt.ylabel("Loss")
            plt.legend()
            plt.grid(True)
            plt.show()

        except (AttributeError, TypeError, KeyError) as e:
            print(f"Could not plot '{loss_name}'. Error retrieving data: {e}")

# %% [markdown]
# ## Imagix
# If we want to use a standard image vae, we can use the Imagix pipeline. Note that only one image dataset is allowed here
# **NOTE**:
# set the datacase in config to DataCase.IMG_TO_IMG

# %%
import autoencodix as acx
from autoencodix.configs.default_config import (
    DefaultConfig,
    DataConfig,
    DataCase,
    DataInfo,
)
import os

IMGROOT = os.path.join("data/images/ALY-2_SYS721/")
IMGMAPPING = os.path.join("data/ALY-2_SYS721_mappings.txt")
NUMFILE = os.path.join("data/AM3_NO2_raw_cell.tsv")

img_config2 = DefaultConfig(
    data_case=DataCase.IMG_TO_IMG,
    checkpoint_interval=10,
    epochs=40,
    reconstruction_loss="bce",
    beta=0.1,
    scaling="MINMAX",
    anneal_function="logistic-late",
    data_config=DataConfig(
        data_info={
            "IMG": DataInfo(
                file_path=IMGROOT,
				scaling="MINMAX",
                data_type="IMG",
            ),
            "ANNO": DataInfo(
                file_path=IMGMAPPING,
                data_type="ANNOTATION",
            ),
        },
    ),
)

imagix = acx.Imagix(config=img_config2)
imagix.preprocess()
imagix.fit()
# Out:
# Given image size is possible, rescaling images to: 64x64
# Successfully loaded 260 images for IMG
# calling normalize image in _process_ing_to_img_case
# --- Running Pairing-Aware Split ---
# anno key: IMG
# dict_keys(['IMG'])
# DP:
# annotation:
#   IMG: 260 samples × 3 features
# img:
#   IMG: 260 items
# k: multi_sc
# k: multi_bulk
# k: annotation
# k: img
# k: from_modality
# k: to_modality
# DP:
# annotation:
#   IMG: 260 samples × 3 features
# img:
#   IMG: 260 items
# k: multi_sc
# k: multi_bulk
# k: annotation
# k: img
# k: from_modality
# k: to_modality
# DP:
# annotation:
#   IMG: 260 samples × 3 features
# img:
#   IMG: 260 items
# k: multi_sc
# k: multi_bulk
# k: annotation
# k: img
# k: from_modality
# k: to_modality
# Converting 182 images to torch.float32 tensors...
# Converting 52 images to torch.float32 tensors...
# Converting 26 images to torch.float32 tensors...
# /Users/maximilianjoas/development/autoencodix_package/src/autoencodix/utils/_imgreader.py:264: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support sep=None with delim_whitespace=False; you can avoid this warning by specifying engine='python'.
#   annotation = pd.read_csv(anno_file, sep=sep)
# Epoch 1 - Train Loss: 3561.8055
# Sub-losses: recon_loss: 3561.8052, var_loss: 0.0002, anneal_factor: 0.0000, effective_beta_factor: 0.0000
# Epoch 1 - Valid Loss: 3586.5237
# Sub-losses: recon_loss: 3586.5237, var_loss: 0.0000, anneal_factor: 0.0000, effective_beta_factor: 0.0000
# Epoch 2 - Train Loss: 3451.9398
# Sub-losses: recon_loss: 3451.9398, var_loss: 0.0000, anneal_factor: 0.0000, effective_beta_factor: 0.0000
# Epoch 2 - Valid Loss: 3502.3296
# Sub-losses: recon_loss: 3502.3296, var_loss: 0.0000, anneal_factor: 0.0000, effective_beta_factor: 0.0000
# Epoch 3 - Train Loss: 3393.2542
# Sub-losses: recon_loss: 3393.2542, var_loss: 0.0000, anneal_factor: 0.0000, effective_beta_factor: 0.0000
# Epoch 3 - Valid Loss: 3391.3834
# Sub-losses: recon_loss: 3391.3834, var_loss: 0.0000, anneal_factor: 0.0000, effective_beta_factor: 0.0000
# Epoch 4 - Train Loss: 3342.5978
# Sub-losses: recon_loss: 3342.5978, var_loss: 0.0000, anneal_factor: 0.0000, effective_beta_factor: 0.0000
# Epoch 4 - Valid Loss: 3291.4681
# Sub-losses: recon_loss: 3291.4681, var_loss: 0.0000, anneal_factor: 0.0000, effective_beta_factor: 0.0000
# Epoch
anneal_factor: 0.0025, effective_beta_factor: 0.0002
# Epoch 19 - Valid Loss: 2911.1899
# Sub-losses: recon_loss: 2911.1364, var_loss: 0.0534, anneal_factor: 0.0025, effective_beta_factor: 0.0002
# Epoch 20 - Train Loss: 2903.4178
# Sub-losses: recon_loss: 2903.3556, var_loss: 0.0622, anneal_factor: 0.0041, effective_beta_factor: 0.0004
# Epoch 20 - Valid Loss: 2904.7016
# Sub-losses: recon_loss: 2904.6424, var_loss: 0.0593, anneal_factor: 0.0041, effective_beta_factor: 0.0004
# Epoch 21 - Train Loss: 2896.1455
# Sub-losses: recon_loss: 2896.0522, var_loss: 0.0933, anneal_factor: 0.0067, effective_beta_factor: 0.0007
# Epoch 21 - Valid Loss: 2898.0264
# Sub-losses: recon_loss: 2897.9384, var_loss: 0.0881, anneal_factor: 0.0067, effective_beta_factor: 0.0007
# Epoch 22 - Train Loss: 2890.5234
# Sub-losses: recon_loss: 2890.3973, var_loss: 0.1261, anneal_factor: 0.0110, effective_beta_factor: 0.0011
# Epoch 22 - Valid Loss: 2891.1896
# Sub-losses: recon_loss: 2891.0673, var_loss: 0.1224, anneal_factor: 0.0110, effective_beta_factor: 0.0011
# Epoch 23 - Train Loss: 2884.8390
# Sub-losses: recon_loss: 2884.6255, var_loss: 0.2135, anneal_factor: 0.0180, effective_beta_factor: 0.0018
# Epoch 23 - Valid Loss: 2884.1316
# Sub-losses: recon_loss: 2883.8504, var_loss: 0.2811, anneal_factor: 0.0180, effective_beta_factor: 0.0018
# Epoch 24 - Train Loss: 2879.9444
# Sub-losses: recon_loss: 2879.7198, var_loss: 0.2246, anneal_factor: 0.0293, effective_beta_factor: 0.0029
# Epoch 24 - Valid Loss: 2875.9408
# Sub-losses: recon_loss: 2875.7043, var_loss: 0.2365, anneal_factor: 0.0293, effective_beta_factor: 0.0029
# Epoch 25 - Train Loss: 2875.6579
# Sub-losses: recon_loss: 2875.3411, var_loss: 0.3168, anneal_factor: 0.0474, effective_beta_factor: 0.0047
# Epoch 25 - Valid Loss: 2872.1163
# Sub-losses: recon_loss: 2871.7906, var_loss: 0.3256, anneal_factor: 0.0474, effective_beta_factor: 0.0047
# Epoch 26 - Train Loss: 2872.5067
# Sub-losses: recon_loss: 2872.0916, var_loss: 0.4151, anneal_factor: 0.0759, effective_beta_factor: 0.0076
# Epoch 26 - Valid Loss: 2872.7055
# Sub-losses: recon_loss: 2872.3191, var_loss: 0.3864, anneal_factor: 0.0759, effective_beta_factor: 0.0076
# Epoch 27 - Train Loss: 2869.8973
# Sub-losses: recon_loss: 2869.3525, var_loss: 0.5448, anneal_factor: 0.1192, effective_beta_factor: 0.0119
# Epoch 27 - Valid Loss: 2866.6286
# Sub-losses: recon_loss: 2866.2197, var_loss: 0.4090, anneal_factor: 0.1192, effective_beta_factor: 0.0119
# Epoch 28 - Train Loss: 2867.1152
# Sub-losses: recon_loss: 2866.5442, var_loss: 0.5710, anneal_factor: 0.1824, effective_beta_factor: 0.0182
# Epoch 28 - Valid Loss: 2869.1929
# Sub-losses: recon_loss: 2868.0337, var_loss: 1.1592, anneal_factor: 0.1824, effective_beta_factor: 0.0182
# Epoch 29 - Train Loss: 2864.9663
# Sub-losses: recon_loss: 2864.0604, var_loss: 0.9059, anneal_factor: 0.2689, effective_beta_factor: 0.0269
# Epoch 29 - Valid Loss: 2866.0165
# Sub-losses: recon_loss: 2865.0273, var_loss: 0.9891, anneal_factor: 0.2689, effective_beta_factor: 0.0269
# Epoch 30 - Train Loss: 2862.5934
# Sub-losses: recon_loss: 2861.7993, var_loss: 0.7941, anneal_factor: 0.3775, effective_beta_factor: 0.0378
# Epoch 30 - Valid Loss: 2861.3840
# Sub-losses: recon_loss: 2860.8356, var_loss: 0.5484, anneal_factor: 0.3775, effective_beta_factor: 0.0378
# Epoch 31 - Train Loss: 2861.0122
# Sub-losses: recon_loss: 2860.0701, var_loss: 0.9421, anneal_factor: 0.5000, effective_beta_factor: 0.0500
# Epoch 31 - Valid Loss: 2860.1421
# Sub-losses: recon_loss: 2859.4621, var_loss: 0.6799, anneal_factor: 0.5000, effective_beta_factor: 0.0500
# Epoch 32 - Train Loss: 2859.5448
# Sub-losses: recon_loss: 2858.7727, var_loss: 0.7721, anneal_factor: 0.6225, effective_beta_factor: 0.0622
# Epoch 32 - Valid Loss: 2859.1415
# Sub-losses: recon_loss: 2858.1358, var_loss: 1.0058, anneal_factor: 0.6225, effective_beta_factor: 0.0622
# Epoch 33 - Train Loss: 2858.7688
# Sub-losses: recon_loss: 2857.9161, var_loss: 0.8527, anneal_factor: 0.7311, effective_beta_factor: 0.0731
# Epoch 33 - Valid Loss: 2863.4366
# Sub-losses: recon_loss: 2861.2169, var_loss: 2.2196, anneal_factor: 0.7311, effective_beta_factor: 0.0731
# Epoch 34 - Train Loss: 2857.3291
# Sub-losses: recon_loss: 2855.4299, var_loss: 1.8992, anneal_factor: 0.8176, effective_beta_factor: 0.0818
# Epoch 34 - Valid Loss: 2856.0616
# Sub-losses: recon_loss: 2854.7422, var_loss: 1.3194, anneal_factor: 0.8176, effective_beta_factor: 0.0818
# Epoch 35 - Train Loss: 2855.6051
# Sub-losses: recon_loss: 2854.7684, var_loss: 0.8367, anneal_factor: 0.8808, effective_beta_factor: 0.0881
# Epoch 35 - Valid Loss: 2855.8693
# Sub-losses: recon_loss: 2853.8891, var_loss: 1.9801, anneal_factor: 0.8808, effective_beta_factor: 0.0881
# Epoch 36 - Train Loss: 2854.5563
# Sub-losses: recon_loss: 2853.2417, var_loss: 1.3146, anneal_factor: 0.9241, effective_beta_factor: 0.0924
# Epoch 36 - Valid Loss: 2852.9600
# Sub-losses: recon_loss: 2851.9688, var_loss: 0.9912, anneal_factor: 0.9241, effective_beta_factor: 0.0924
# Epoch 37 - Train Loss: 2854.1272
# Sub-losses: recon_loss: 2853.0628, var_loss: 1.0644, anneal_factor: 0.9526, effective_beta_factor: 0.0953
# Epoch 37 - Valid Loss: 2852.2109
# Sub-losses: recon_loss: 2851.2761, var_loss: 0.9347, anneal_factor: 0.9526, effective_beta_factor: 0.0953
# Epoch 38 - Train Loss: 2853.4436
# Sub-losses: recon_loss: 2852.6716, var_loss: 0.7719, anneal_factor: 0.9707, effective_beta_factor: 0.0971
# Epoch 38 - Valid Loss: 2850.6424
# Sub-losses: recon_loss: 2850.0337, var_loss: 0.6087, anneal_factor: 0.9707, effective_beta_factor: 0.0971
# Epoch 39 - Train Loss: 2851.5841
# Sub-losses: recon_loss: 2850.5235, var_loss: 1.0606, anneal_factor: 0.9820, effective_beta_factor: 0.0982
# Epoch 39 - Valid Loss: 2849.1815
# Sub-losses: recon_loss: 2848.5297, var_loss: 0.6517, anneal_factor: 0.9820, effective_beta_factor: 0.0982
# Epoch 40 - Train Loss: 2850.8000
# Sub-losses: recon_loss: 2849.7660, var_loss: 1.0340, anneal_factor: 0.9890, effective_beta_factor: 0.0989
# Epoch 40 - Valid Loss: 2849.4826
# Sub-losses: recon_loss: 2848.3600, var_loss: 1.1226, anneal_factor: 0.9890, effective_beta_factor: 0.0989

# %%
imagix.config.data_case
# Out:
# <DataCase.IMG_TO_IMG: 'IMG<->IMG'>

# %%
imagix.predict()
# Out:
# Result Object Public Attributes:
# ------------------------------
# latentspaces: TrainingDynamics object
# sample_ids: TrainingDynamics object
# reconstructions: TrainingDynamics object
# mus: TrainingDynamics object
# sigmas: TrainingDynamics object
# losses: TrainingDynamics object
# sub_losses: LossRegistry(_losses={'recon_loss': TrainingDynamics(), 'var_loss': TrainingDynamics(), 'anneal_factor': TrainingDynamics(), 'effective_beta_factor': TrainingDynamics()})
# preprocessed_data: Tensor of shape (0,)
# model: ImageVAEArchitecture
# model_checkpoints: TrainingDynamics object
# datasets: DatasetContainer(train=<autoencodix.data._image_dataset.ImageDataset object at 0x345a654b0>, valid=<autoencodix.data._image_dataset.ImageDataset object at 0x32c0f6d70>, test=<autoencodix.data._image_dataset.ImageDataset object at 0x32c0f43a0>)
# new_datasets: DatasetContainer(train=None, valid=None, test=None)
# adata_latent: AnnData object with n_obs × n_vars = 52 × 16
#     uns: 'var_names'
# final_reconstruction: <autoencodix.data._image_dataset.ImageDataset object at 0x3ae514640>
# sub_results: None
# sub_reconstructions: None
# embedding_evaluation: Empty DataFrame
# Columns: []
# Index: []

# %%
import matplotlib.pyplot as plt
r2 = imagix.result
r2.final_reconstruction
sample_img = r2.final_reconstruction.data[17, :, :, :]
sample_img = sample_img.squeeze()

plt.imshow(sample_img, cmap="grey")

# %%
sample_img
# Out:
# tensor([[0.0528, 0.0050, 0.0103,  ..., 0.0131, 0.0146, 0.0586],
#         [0.0308, 0.0110, 0.0050,  ..., 0.0091, 0.0040, 0.0397],
#         [0.0157, 0.0043, 0.0088,  ..., 0.0065, 0.0070, 0.0292],
#         ...,
#         [0.0085, 0.0021, 0.0011,  ..., 0.0093, 0.0041, 0.0215],
#         [0.0152, 0.0011, 0.0038,  ..., 0.0056, 0.0097, 0.0113],
#         [0.1278, 0.0285, 0.0243,  ..., 0.0363, 0.0441, 0.1082]])

# %%
sample_img = r2.reconstructions.get(split="test", epoch=-1)
sample_img = sample_img[0,:,:,:]
sample_img = sample_img.squeeze()
sample_img.shape
# Out:
# (64, 64)

# %%
import matplotlib.pyplot as plt

plt.imshow(sample_img, cmap="grey")

# %%
plot_losses(r2)

# %%
imagix._datasets.train.data[0]
# Out:
# tensor([[[0.0652, 0.0870, 0.0652,  ..., 0.0870, 0.0652, 0.0652],
#          [0.0652, 0.0435, 0.0435,  ..., 0.0435, 0.0652, 0.0435],
#          [0.0435, 0.0652, 0.0652,  ..., 0.0435, 0.0435, 0.0435],
#          ...,
#          [0.0217, 0.0435, 0.0435,  ..., 0.0435, 0.0217, 0.0217],
#          [0.0435, 0.0435, 0.0435,  ..., 0.0217, 0.0217, 0.0217],
#          [0.0435, 0.0435, 0.0435,  ..., 0.0435, 0.0217, 0.0217]]])

# %%
loader = imagix._trainer._trainloader
for batch in loader:
    a = batch
    break

# %%
type(a)
# Out:
# list

# %% [markdown]
# a

# %%
len(a)
# Out:
# 3

# %%
a[1].max()
# Out:
# tensor(1., device='mps:0')
